# %% [markdown]
# # Feature data processing
#
# This notebook is to generate a feature table (where peaks are the rows and each column shows if a transcription factor is found at that peak)
#
# - We will break it into steps

# %% [markdown]
# These are our important files
#
# - The peak ids from our experiment and thier locations are in
# `/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/all_basson_cerebellarWTminR123_peaks.bed`
# - The overlap of these peaks with the ChIPAtlas dataset (Our 'long' datatable) is in
# `/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/basson_overlap_with_chipatlas_TF.bed`
#     - This contains our peak ids (e.g. atac_de_peak_chr1_3094800_3095300) and what datasets they overlap with (SRX5237754) **NOTE THIS FILE IS TOO BIG TO DO MUCH WITH USE OTHER FILES INSTEAD**
#
# - This file describes the peak datasets for each tissue/factor and gives the file name of how to download them
#     - `/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/fileList.tab`
#     - We will use this file instead to get the names of the bedfiles to download and overlap and details about whats in the files

# %%
import pandas as pd

# %% [markdown]
# Read in the files that summarise the data we want to overlap with our peaks

# %%
peak_files = pd.read_table('/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/fileList.tab',header=None)
peak_files.columns = ['file_name','genome','data_type','antigen','cell_type_class','cell_type','threshold','experimental_ids']

# %%
# subset the peakfiles to the mouse (mm10) genome 
peak_files_mm10 = peak_files[peak_files['genome']=='mm10'].copy()
# look at datatypes - we only want TF and others --> 143000 cell types 
peak_files_mm10.groupby('data_type').count().reset_index()
# Out:
#         data_type  file_name  genome  antigen  cell_type_class  cell_type
# 0        ATAC-Seq       2520    2520     2520             2520       2516  \
# 1   Bisulfite-Seq        308     308      308              308        307
# 2       DNase-seq        576     576      576              576        572
# 3         Histone       5040    5040     5040             5040       5036
# 4   Input control       2548    2548     2548             2548       2548
# 5  No description        860     860      768              860        856
# 6  RNA polymerase        928     928      928              928        928
# 7  TFs and others      14300   14300    14300            14300      14300
# 8    Unclassified       1596    1596     1596             1596       1596
#
#    threshold  experimental_ids
# 0       2520              2451
# 1        308               307
# 2        576               551
# 3       5040              5028
# 4       2548              2532
# 5        860               844
# 6        928               924
# 7      14300             14268
# 8       1596              1592

# %%
# subset this table to TF (transcription factors) and see what tissues there are in the dataset 
peak_files_mm10_TFs = peak_files_mm10[peak_files_mm10['data_type']=='TFs and others'].copy()

# %%
pd.set_option('display.max_rows', 500)

# %%
peak_files_mm10_TFs.groupby(['cell_type_class','cell_type']).count()
# Out:
#                                        file_name  genome  data_type  antigen
# cell_type_class cell_type
# Adipocyte       -                            164     164        164      164  \
#                 Adipocytes                     4       4          4        4
#                 Adipose Tissue                 4       4          4        4
#                 Brown adipocytes               4       4          4        4
#                 Brown preadipocytes            4       4          4        4
# ...                                          ...     ...        ...      ...
# Uterus          -                             52      52         52       52
#                 Decidua                        4       4          4        4
#                 Endometriotic lesions          4       4          4        4
#                 Endometrium                    4       4          4        4
#                 Uterus                         4       4          4        4
#
#                                        threshold  experimental_ids
# cell_type_class cell_type
# Adipocyte       -                            164               160
#                 Adipocytes                     4                 4
#                 Adipose Tissue                 4                 4
#                 Brown adipocytes               4                 4
#                 Brown preadipocytes            4                 4
# ...                                          ...               ...
# Uterus          -                             52                52
#                 Decidua                        4                 4
#                 Endometriotic lesions          4                 4
#                 Endometrium                    4                 4
#                 Uterus                         4                 4
#
# [549 rows x 6 columns]

# %% [markdown]
# What are the cell types we want out of this - all the cerebellum ones and granule neuron progenitors and neural progenitors? Or all of them? Lets go for all of them for now we can always subset to just the neuronal ones later

# %% [markdown]
# How many different antigens (TFs) are there

# %%
print(peak_files_mm10_TFs.antigen.nunique())
# Out:
# 884

# %%
print(peak_files_mm10_TFs.antigen.unique())
# Out:
# ['-' 'GFP' 'Etv5' 'Bnc1' 'Foxo1' 'Smarca4' 'Esrrb' 'Rreb1' 'Rb1' 'Cebpb'
#  'T' 'Hnf4a' 'Hdac4' 'Yy2' 'Kdm5c' 'Sp6' 'Smarcc1' 'Mbd3' 'Ehmt2' 'Gata4'
#  'Hnf1b' 'Tbx3' 'Thrap3' 'Ctr9' 'Supt5' 'Rpa2' 'Hnf1a' 'Wt1' 'Ar' 'Smad3'
#  'Smc5' 'Kdm4d' 'Nfatc1' 'Satb2' 'Tcf7l2' 'Hcfc1' 'Top2b' 'Bmi1' 'E2f3'
#  'Nfkbia' 'Ncor1' 'Hsf1' 'Arntl' 'Ezh2' 'Smad4' 'Gtf2f1' 'Ing5' 'Kdm6b'
#  'Elf4' 'Rara' 'Gabpa' 'Uhrf2' 'Irf7' 'Ddx21' 'Hif1a' 'Sp9' 'Nfkb1'
#  'Biotin' 'Trim28' 'Bcl6' 'Foxa2' 'Tcf3' 'Cdx2' 'Cbx7' 'Ddx5' 'Rest'
#  'Ctf1' 'E4f1' 'Taf7l' 'Tcf7' 'Pou3f2' 'Wdr82' 'Smc1a' 'Crebbp' 'Duxbl1'
#  'Ago2' 'Hoxc8' 'Mecp2' 'Nfe2l2' 'Sin3b' 'Rnf2' 'Esrra' 'Mef2c' 'Ncaph2'
#  'Phf6' 'Nfia' 'Junb' 'Onecut2' 'Alkbh5' 'Nelfa' 'Klf4' 'Epitope tags'
#  'Wdr61' 'Smc3' 'Ikzf1' 'Myc' 'Suz12' 'Foxp1' 'Pcgf1' 'Ctnnb1' 'L3mbtl2'
#  'Nbn' 'Zfp191' 'Sox17' 'Sox4' 'Irf4' 'Ncoa3' 'Sox2' 'Zbtb2' 'Brd4' 'Ctcf'
#  'Sox9' 'Arid1b' 'Kat2a' 'Zeb1' 'Srf' 'Matr3' 'Ebf2' 'Trp53' 'Irf9'
#  'Prox1' 'Med1' 'Ssu72' 'Brd3' 'Sp1' 'Safb' 'Usf2' 'Hnf4g' 'Ets1' 'Erg'
#  'Cry1' 'Kdm6a' 'Lmo2' 'Aff4' 'Tead1' 'Atoh1' 'Gsk3b' 'Klf5' 'Bcl11b'
#  'Hdac2' 'Ptbp1' 'Smarcb1' 'Mta2' 'Tnni2' 'Hdac1' 'Pax7' 'Zkscan1' 'Ctbp2'
#  'Atrx' 'Stat3' 'Sox11' 'Cebpg' 'Taf2' 'Taf9b' 'Stat5a' 'Rxra' 'Pcgf6'
#  'Ascl1' 'Gli2' 'Mre11a' 'Nr1d2' 'Cbx2' 'Hnrnpu' 'Thap1' 'Sin3a' 'Srsf1'
#  'Mpnd' 'Cdk9' 'Tcf12' 'Pwp1' 'Zfp281' 'Crtc2' 'Rfx3' 'Six4' 'Creb3l2'
#  'Supt4a' 'HBx' 'Sirt7' 'Foxg1' 'Kdm1a' 'Mef2a' '0610010K14Rik' 'Tlx1'
#  'Rtf1' 'Pou2f3' 'Gfi1' 'Nsl1' 'Emx2' 'Asxl1' 'Pou2af1' 'Atf2' 'Lef1'
#  'Atf4' 'Ubtf' 'Cirh1a' 'Tbx4' 'Pax6' 'Parp1' 'E2f6' 'Grhl2' 'Cas9'
#  'Jmjd6' 'Dlx1' 'Cbfb' 'Pbx1' 'Gtf2a2' 'Zc3h4' 'Mycn' 'Wdr11' 'Gcm1'
#  'Tal1' 'Zmiz1' 'Nfyb' 'Rpa1' 'Pds5b' 'Tfap2a' 'Twist1' 'Rad21' 'Foxk2'
#  'Fosl1' 'Rbpjl' 'Hdac3' 'Socs1' 'Rfx1' 'Stag1' 'Pparg' 'Prdm13' 'Cebpa'
#  'Kdm2b' 'Men1' 'Six2' 'Eed' 'Irf5' 'Cbx4' 'Snai2' 'Nr3c1' 'Grhl3' 'Sox6'
#  'Dppa4' 'Setdb1' 'Wtap' 'Acaa2' 'Setd1a' 'Tbr1' 'Baz1a' 'Ell' 'Mybl1'
#  'Rif1' 'Pax5' 'Pml' 'Pcgf3' 'Yy1' 'Cpsf3l' 'Tcf4' 'Nelfe' 'Zfp335'
#  'Prdm15' 'Stag2' 'Cebpd' 'Ncl' 'Bcor' 'Creb1' 'Jarid2' 'Fosb' 'Myt1l'
#  'Ep300' 'Olig2' 'Tbx20' 'Fgfr1' 'Hoxa9' 'Rela' 'Cbfa2t3' 'Elk4' 'Crx'
#  'Dnttip1' 'Arid1a' 'Dlx3' 'Chd4' 'Dhx9' 'Mkl1' 'Kmt2c' 'Fam60a' 'Trim33'
#  'Nkx2-2' 'Ddx1' 'Smad2' 'Ebf4' 'Chd8' 'Phf7' 'Rfx2' 'Prm1' 'Jun' 'Snai1'
#  'Hic2' 'Sirt1' 'Cxxc1' 'Ahr' 'Batf' 'DNA-RNA hybrid' 'Ebf1' 'Dmrt1'
#  'Pitx1' 'Kmt2b' 'Lin9' 'Gps2' 'AML1-ETO' 'Mta1' 'Lhx6' 'Ascl2' 'Sox13'
#  'Lmnb1' 'Brwd1' 'Tet1' 'Tead4' 'Fev' 'Ss18' 'Spi1' 'Wdr5' 'Rnf20' 'Dmap1'
#  'Leo1' 'Peg3' 'Irf3' 'Hdgf2' 'Usp7' 'Rbfox2' '5-hmC' 'Gli1' 'Isl1' 'Eloa'
#  'Gad1' 'Mafg' 'Mtor' 'Mitf' 'Arid3a' 'Yap1' 'Zscan4c' 'Satb1' 'Pspc1'
#  'Kdm4a' 'Zbtb7b' 'Stat5b' 'Nfyc' 'Myod1' 'Irf8' 'Tead2' 'Ncor2' 'Zfp410'
#  'Stab1' 'Foxk1' 'Dmc1' 'Ercc3' 'Hoxb4' 'Rora' 'Dpf3' 'Glyr1' 'Nfil3'
#  'Stat1' 'Relb' 'Foxh1' 'Six1' 'Ovol1' 'Terf2ip' 'Nfix' 'Cbx8' 'Fli1'
#  'Tbp' 'Gata3' 'Rbbp5' 'Tet3' 'Prmt5' 'Fosl2' 'Pgr' 'Nr4a1' 'Nkx2-1'
#  'Brd9' 'Etv2' 'Runx2' 'Zfp143' 'Hmgn2' 'Elf1' 'Zic2' 'Foxo3' 'Setd5'
#  'Tcf7l1' 'Kdm5a' 'Otx2' 'Med14' 'Nkx6-1' 'Suv39h2' 'Pcna' 'Mtf2' 'Hoxc10'
#  'Maf' 'Cux2' 'Bcl11a' 'Ikzf2' 'Utf1' 'Med12' 'Ash1l' 'Ino80' 'Ruvbl2'
#  'Lhx2' 'Pcgf2' 'Pou2f1' 'ADP-ribose' 'Pou3f1' 'Brdt' 'Prdm14' 'Chd1'
#  'Actb' 'Max' 'Runx1' 'Cbx5' 'Rai1' 'Bbx' 'Myb' 'Gata2' 'Timeless' 'Adnp'
#  'Whsc1l1' 'Stra8' 'Zc3h10' 'Prdm1' 'Taf3' 'Rbpj' 'Usf1' 'Sfmbt2' 'Mnx1'
#  'Srebf1' 'Mysm1' 'Sumo1' 'Nfe2' 'Mnt' 'Onecut1' 'Kdm2a' 'Zc3h11a'
#  'Neurog2' 'Klf9' 'Tbx5' 'Med26' 'Usp16' 'Id2' 'Ovol2' 'Hexim1' 'Nrf1'
#  'Runx3' 'Jmjd1c' 'Phf2' 'Bap1' 'Pknox1' 'Daxx' 'Nr0b2' 'Art1' 'Safb2'
#  'Gata1' 'Phf8' 'Ogdh' 'Phrf1' 'Clock' 'Utp3' 'Zfpm1' 'Nfya' 'Mafk'
#  'Hoxd13' 'Nr1d1' 'Meis1' 'Egr2' 'Fos' 'Nup210' 'Carm1' 'Sp3' 'Zic1'
#  'Prdm10' 'Dbp' 'Kdm5b' 'Heyl' 'Tet2' 'Obox1' 'Nup107' 'Rcor2' 'Gtf2e2'
#  'Ehf' 'Kmt2d' 'Arnt' 'Foxa1' 'Sirt6' 'Dpy30' 'Rad51' 'Phc2' 'Irf2'
#  'Dppa2' 'Terf1' 'Dnmt3a' 'Hira' 'Pawr' 'Foxc1' 'Bach1' 'Brca2' 'Mlxipl'
#  'Cbx3' 'Arid2' 'Tfe3' 'Mau2' 'Maz' '8-Hydroxydeoxyguanosine' 'Dnmt3b'
#  'Tgif1' 'Gtf3c1' 'Propionyllysine' 'Baz1b' 'Trp63' 'Msl2' 'Brca1' 'Elf5'
#  'Zbtb17' 'Nlrp3' 'Fam208a' 'Elob' 'BrdU' 'E2f4' 'Nr2f2' 'Tfap2c' 'Batf3'
#  'Cbx1' 'Zmynd11' 'Ncapd3' 'Taf1' 'Tbl1x' 'Foxj2' 'Mettl3' 'Hoxd9' 'Uhrf1'
#  'Nr1h4' 'Foxp3' 'Nanog' 'Thra' 'Lyl1' 'Mesp1' 'Dr1' 'Stat4' 'Hand2'
#  'Foxp2' 'Hoxb13' 'Lmx1b' 'Lhx3' 'Meiosin' 'Nup153' 'Esr1' 'Cdc73' 'Taf12'
#  'Phf5a' 'Epop' 'Aicda' 'Egr1' 'Ell2' 'Mafa' 'Pou5f1' 'Eomes' 'Rel' 'Ogt'
#  'Ppard' 'Klf15' 'Supt16' 'Btaf1' 'Hopx' 'Zfp42' 'Mllt10' 'Nr0b1' 'Sap130'
#  'Sox3' 'Grip1' 'Kat5' 'Top1' 'H1foo' 'Maff' 'Klf6' 'Xrn2' 'Nlrc5' 'Bach2'
#  'Irf1' 'Arid5a' 'Tfcp2l1' 'Prdm16' 'Kdm3a' 'Npas4' 'Sap18' 'N6amt1'
#  'Nfib' 'Hoxa13' 'Hmga2' 'Mphosph8' 'Irf2bp2' 'Dmrtb1' 'Gadd45a' 'Macf1'
#  'Ppara' 'Aire' 'Tmem131' 'Kat8' 'Gmnn' 'Kdm4c' 'Srebf2' 'Sp110' 'Rybp'
#  'Ell3' 'Vsx2' 'Nr5a1' 'Rbp2' 'Anp32e' 'Etv6' 'RFP' 'Prrx1' 'Foxl2'
#  'Pbrm1' 'Paf1' 'Mettl14' 'Arid4b' 'Neurod1' 'Rec8' 'Trim24' 'Xbp1' '5-mC'
#  'Prdm9' 'Stat2' 'Ybx1' 'Taf10' 'Rbbp4' 'Ptf1a' 'Dicer1' 'Was' 'Trps1'
#  'Dnmt3l' 'Ahcy' 'Nr5a2' 'Zfp541' 'Foxa3' 'Hdac7' 'Nacc1' 'Gfi1b' 'Dnmt1'
#  'Klf3' 'Hes1' 'Zbtb11' 'Sfmbt1' 'Acss2' 'Erf' 'Tbx21' 'Foxf1' 'Dpf2'
#  'Nr1i2' 'Zbtb24' 'Foxc2' 'Taf15' 'Nucks1' 'Tox' 'Bhlhe41' 'Zfp961'
#  'Notch1' 'Tle1' 'O-GlcNAc' 'Ncoa2' 'Hsf2' 'Supt6' 'E2f1' 'Chd2' 'Usp22'
#  'Drosha' 'Chd7' 'Thoc5' 'Pds5a' 'Ints5' 'Ldb1' 'RAF1' 'Naa10' 'Auts2'
#  'Ncoa1' 'Nkx2-5' 'Nkx3-2' 'Shox2' 'Kdm3b' 'Ing1' 'Sumo2' 'Smad1' 'Vdr'
#  'Lhx5' 'Srcap' 'Myf5' 'Tmpo' 'Cdk8' 'Succinyllysine' 'Hoxa11' 'Nr1h3'
#  'Gata6' 'Cxxc5' 'Smarca5' 'Mef2d' 'Atf3' 'Crotonyl lysine' 'Sox10'
#  'Hells' 'Chuk' 'Wiz' 'Ezh1' 'Sox15' 'Msl1' 'Baz2a' 'Cbfa2t2' 'Tfam'
#  'Hnrnpul1' 'Gtf2b' 'Rad23b' 'Thap11' 'Mcrs1' 'Tgif2' 'Ctcfl' 'Atf7ip'
#  'Crtc3' 'Sall4' 'Ddit3' 'Smchd1' 'Prdm5' 'Utp6' 'Qk' 'Mkl2' 'Raf1'
#  'Phf20' 'Nfatc2' 'Sall1' 'Atf7' 'Npas3' 'Klf2' 'Rarb' 'Dgcr8' 'Nr1h2'
#  'Tfap4' 'Ttf1' 'Dendra2' 'Ccnk' 'Gckr' 'Kat7' 'Atm' 'Ash2l' 'Hoxc9'
#  'Elk1' 'Paxip1' 'Ppargc1b' 'Fbxo21' 'Raly' 'Nelfb' 'Chaf1b' 'CEBPA'
#  'Ddx18' 'Tbpl1' 'Polr1a' 'Spib' 'Pax3' 'Fo' 'Ssrp1' 'Htatsf1' 'Kat2b'
#  'Cebpe' 'Nfe2l1' 'Ythdc1' 'Asxl3' 'Neurod2' 'Nipbl' 'Zfp384' 'Pcgf5'
#  'Zic3' 'Smarcad1' 'Pagr1a' 'Zfp322a' 'Samd7' 'Jund' 'Gli3' 'Phf19'
#  'Zscan5b' 'Stat6' 'Mafb' 'Hdac6' 'Cdk7' 'Hnrnpl' 'Zfp64' 'Myog' 'Top2a'
#  'Elk3' 'L3mbtl3' 'Smad6' 'Wapl' 'Cdyl' 'Naca' 'Rorc' 'Bhlhe40' 'Tle3'
#  'Nup98' 'Spin1' 'Plagl1' 'Hoxc6' 'Phc1' 'Zfp708' 'Pygo2' 'Mapk8'
#  'Tsc22d3' 'Brd7' 'Pou2f2' 'Esr2' 'Pdx1' 'Hdac5' 'Rbbp7' 'Smyd2' 'Zmynd8'
#  'Hoxc13' 'Ints3' 'Ncapg' 'Srsf2' 'Zfp57' 'Yeats4' 'Mbd2' 'Nono' 'Msh2'
#  'Brd2' 'Ep400' 'Insm1' 'Tdg' 'Pax8' 'Npm1' 'Cd38' 'Psip1' 'Kdm4b'
#  'Zbtb16' 'Nkx3-1' 'Rarg' 'Zfp217' 'Hnrnpk' 'Ruvbl1' 'Scml2' 'Hoxb1'
#  'Setd2' 'Aebp2' 'Nfic' 'Trmt112' 'Msh6' 'Thrb' 'Kmt2a' 'Smarca2' 'Sox30'
#  'Sp7' 'Sox5' 'Morc3' 'Mbd1' 'Aff3' 'Myo1c' 'Mllt3' 'Glis3'
#  'Lysin homocysteine' 'Phf10' 'Dppa3' 'Spen' 'Med24' 'Esrrg' 'Rag1'
#  'Tcfl5' 'Ikzf3' 'Ets2' 'Htt' 'Lrrfip1' 'Nfat5' 'Med4' 'Smad7' 'Hdgfrp2'
#  'Lmna' 'Hand1' 'Kansl3' 'Tfeb' 'Med23' 'Banp' 'Dnajc2' 'Mxi1' 'Ccar1'
#  'Butyryllysine' 'Park7' 'Tbx19' 'Rag2']

# %% [markdown]
# We want to download the peaks for each of these factors - we need to get the file names from the table to see what they are specified as

# %%
# have a look at what the neural file names are like 
peak_files_mm10_TFs[peak_files_mm10_TFs['cell_type_class']=='Neural'].head(100)
# Out:
#                                                file_name genome
# 129384                          Oth.Neu.20.AllAg.AllCell   mm10  \
# 129656                          Oth.Neu.10.AllAg.AllCell   mm10
# 129864                          Oth.Neu.05.AllAg.AllCell   mm10
# 129898                          Oth.Neu.50.AllAg.AllCell   mm10
# 130289                          Oth.Neu.10.Hif1a.AllCell   mm10
# 130351                         Oth.Neu.10.Pou3f2.AllCell   mm10
# 130381                          Oth.Neu.05.Esrra.AllCell   mm10
# 130382                          Oth.Neu.50.Mef2c.AllCell   mm10
# 130385                           Oth.Neu.10.Nfia.AllCell   mm10
# 130404                  Oth.Neu.20.AllAg.Olfactory_Nerve   mm10
# 130462                           Oth.Neu.20.Brd4.AllCell   mm10
# 130568                          Oth.Neu.50.Kdm5c.AllCell   mm10
# 130613                         Oth.Neu.10.Zfp191.AllCell   mm10
# 130624                           Oth.Neu.10.Sox4.AllCell   mm10
# 130655                          Oth.Neu.10.Foxg1.AllCell   mm10
# 130659                          Oth.Neu.50.Mef2a.AllCell   mm10
# 130669                           Oth.Neu.50.Gfi1.AllCell   mm10
# 130675                           Oth.Neu.50.Emx2.AllCell   mm10
# 130704                          Oth.Neu.10.Cebpb.AllCell   mm10
# 130751  Oth.Neu.10.AllAg.Arcuate_Nucleus_of_Hypothalamus   mm10
# 130795                             Oth.Neu.20.AllAg.Glia   mm10
# 130814                           Oth.Neu.20.Nfia.AllCell   mm10
# 130829                           Oth.Neu.50.Mycn.AllCell   mm10
# 130845  Oth.Neu.50.AllAg.Retinal_Rod_Photoreceptor_Cells   mm10
# 130909                          Oth.Neu.05.Nelfe.AllCell   mm10
# 130915                          Oth.Neu.20.Stag2.AllCell   mm10
# 130938  Oth.Neu.05.AllAg.Oligodendrocyte_precursor_cells   mm10
# 130987                            Oth.Neu.10.Crx.AllCell   mm10
# 131055                         Oth.Neu.20.AllAg.Neuro-2a   mm10
# 131057                            Oth.Neu.10.Jun.AllCell   mm10
# 131063       Oth.Neu.10.AllAg.Induced_neural_progenitors   mm10
# 131069                         Oth.Neu.20.Zfp191.AllCell   mm10
# 131070                          Oth.Neu.20.Sirt1.AllCell   mm10
# 131122                           Oth.Neu.10.Med1.AllCell   mm10
# 131127                         Oth.Neu.50.Biotin.AllCell   mm10
# 131163                           Oth.Neu.05.Tet1.AllCell   mm10
# 131251                           Oth.Neu.05.Rxra.AllCell   mm10
# 131353                 Oth.Neu.50.AllAg.Striatal_neurons   mm10
# 131357                  Oth.Neu.50.AllAg.Medulloblastoma   mm10
# 131399                           Oth.Neu.05.Nfix.AllCell   mm10
# 131405                           Oth.Neu.05.Mafg.AllCell   mm10
# 131416                          Oth.Neu.20.Pcgf3.AllCell   mm10
# 131417       Oth.Neu.10.AllAg.Superior_Cervical_Ganglion   mm10
# 131446                          Oth.Neu.50.Lmnb1.AllCell   mm10
# 131449                            Oth.Neu.10.AllAg.C17-2   mm10
# 131470              Oth.Neu.05.AllAg.Hippocampal_neurons   mm10
# 131484                          Oth.Neu.20.Foxo3.AllCell   mm10
# 131516                 Oth.Neu.20.AllAg.Striatal_neurons   mm10
# 131552                         Oth.Neu.05.Zfp191.AllCell   mm10
# 131591                          Oth.Neu.50.Runx1.AllCell   mm10
# 131622                       Oth.Neu.05.Timeless.AllCell   mm10
# 131626                   Oth.Neu.50.AllAg.Olfactory_Bulb   mm10
# 131639                           Oth.Neu.50.Pax7.AllCell   mm10
# 131643                           Oth.Neu.50.Junb.AllCell   mm10
# 131676                           Oth.Neu.20.Chd8.AllCell   mm10
# 131707                          Oth.Neu.05.Top2b.AllCell   mm10
# 131709                           Oth.Neu.10.Cbx8.AllCell   mm10
# 131740                        Oth.Neu.10.Onecut1.AllCell   mm10
# 131776                            Oth.Neu.05.Jun.AllCell   mm10
# 131782                  Oth.Neu.20.AllAg.Medulloblastoma   mm10
# 131808                           Oth.Neu.05.Gfi1.AllCell   mm10
# 131845                          Oth.Neu.50.Top2b.AllCell   mm10
# 131936                Oth.Neu.10.AllAg.Neural_Stem_Cells   mm10
# 131943                          Oth.Neu.50.Carm1.AllCell   mm10
# 131981                          Oth.Neu.05.Hdac1.AllCell   mm10
# 132048                           Oth.Neu.10.Phf8.AllCell   mm10
# 132106  Oth.Neu.20.AllAg.Retinal_Rod_Photoreceptor_Cells   mm10
# 132115                          Oth.Neu.50.AllAg.Neurons   mm10
# 132146                           Oth.Neu.10.Rela.AllCell   mm10
# 132185                           Oth.Neu.20.Cbx3.AllCell   mm10
# 132226                           Oth.Neu.10.Mycn.AllCell   mm10
# 132227                  Oth.Neu.50.AllAg.Corpus_Striatum   mm10
# 132254                         Oth.Neu.20.Crebbp.AllCell   mm10
# 132298                         Oth.Neu.50.AllAg.Neuro-2a   mm10
# 132373                         Oth.Neu.20.Nup153.AllCell   mm10
# 132412                     Oth.Neu.05.AllAg.Neurofibroma   mm10
# 132446  Oth.Neu.20.AllAg.Neuroepithelial_progenitor_cell   mm10
# 132466                           Oth.Neu.10.Ctcf.AllCell   mm10
# 132571                          Oth.Neu.05.Arntl.AllCell   mm10
# 132635                           Oth.Neu.20.Rest.AllCell   mm10
# 132649                          Oth.Neu.20.Nr2f2.AllCell   mm10
# 132654                       Oth.Neu.10.AllAg.Astrocytes   mm10
# 132734                Oth.Neu.10.AllAg.Nucleus_Accumbens   mm10
# 132775                          Oth.Neu.05.Foxg1.AllCell   mm10
# 132828                         Oth.Neu.05.Crebbp.AllCell   mm10
# 132832                         Oth.Neu.50.Dnmt3a.AllCell   mm10
# 132833                           Oth.Neu.50.Vsx2.AllCell   mm10
# 132839                           Oth.Neu.20.Gfi1.AllCell   mm10
# 132890                           Oth.Neu.20.Tcf3.AllCell   mm10
# 132907                  Oth.Neu.10.AllAg.Cortical_neuron   mm10
# 132911                          Oth.Neu.05.Parp1.AllCell   mm10
# 132932                        Oth.Neu.20.Mettl14.AllCell   mm10
# 132991                          Oth.Neu.50.Cebpa.AllCell   mm10
# 133020                         Oth.Neu.10.Dnmt3a.AllCell   mm10
# 133021                          Oth.Neu.20.Stat3.AllCell   mm10
# 133071                Oth.Neu.05.AllAg.Cerebellar_Vermis   mm10
# 133077                     Oth.Neu.05.AllAg.Brain_cortex   mm10
# 133080                          Oth.Neu.05.Npas4.AllCell   mm10
# 133126                            Oth.Neu.05.Crx.AllCell   mm10
# 133148                           Oth.Neu.05.Sox4.AllCell   mm10
#
#              data_type   antigen cell_type_class
# 129384  TFs and others         -          Neural  \
# 129656  TFs and others         -          Neural
# 129864  TFs and others         -          Neural
# 129898  TFs and others         -          Neural
# 130289  TFs and others     Hif1a          Neural
# 130351  TFs and others    Pou3f2          Neural
# 130381  TFs and others     Esrra          Neural
# 130382  TFs and others     Mef2c          Neural
# 130385  TFs and others      Nfia          Neural
# 130404  TFs and others         -          Neural
# 130462  TFs and others      Brd4          Neural
# 130568  TFs and others     Kdm5c          Neural
# 130613  TFs and others    Zfp191          Neural
# 130624  TFs and others      Sox4          Neural
# 130655  TFs and others     Foxg1          Neural
# 130659  TFs and others     Mef2a          Neural
# 130669  TFs and others      Gfi1          Neural
# 130675  TFs and others      Emx2          Neural
# 130704  TFs and others     Cebpb          Neural
# 130751  TFs and others         -          Neural
# 130795  TFs and others         -          Neural
# 130814  TFs and others      Nfia          Neural
# 130829  TFs and others      Mycn          Neural
# 130845  TFs and others         -          Neural
# 130909  TFs and others     Nelfe          Neural
# 130915  TFs and others     Stag2          Neural
# 130938  TFs and others         -          Neural
# 130987  TFs and others       Crx          Neural
# 131055  TFs and others         -          Neural
# 131057  TFs and others       Jun          Neural
# 131063  TFs and others         -          Neural
# 131069  TFs and others    Zfp191          Neural
# 131070  TFs and others     Sirt1          Neural
# 131122  TFs and others      Med1          Neural
# 131127  TFs and others    Biotin          Neural
# 131163  TFs and others      Tet1          Neural
# 131251  TFs and others      Rxra          Neural
# 131353  TFs and others         -          Neural
# 131357  TFs and others         -          Neural
# 131399  TFs and others      Nfix          Neural
# 131405  TFs and others      Mafg          Neural
# 131416  TFs and others     Pcgf3          Neural
# 131417  TFs and others         -          Neural
# 131446  TFs and others     Lmnb1          Neural
# 131449  TFs and others         -          Neural
# 131470  TFs and others         -          Neural
# 131484  TFs and others     Foxo3          Neural
# 131516  TFs and others         -          Neural
# 131552  TFs and others    Zfp191          Neural
# 131591  TFs and others     Runx1          Neural
# 131622  TFs and others  Timeless          Neural
# 131626  TFs and others         -          Neural
# 131639  TFs and others      Pax7          Neural
# 131643  TFs and others      Junb          Neural
# 131676  TFs and others      Chd8          Neural
# 131707  TFs and others     Top2b          Neural
# 131709  TFs and others      Cbx8          Neural
# 131740  TFs and others   Onecut1          Neural
# 131776  TFs and others       Jun          Neural
# 131782  TFs and others         -          Neural
# 131808  TFs and others      Gfi1          Neural
# 131845  TFs and others     Top2b          Neural
# 131936  TFs and others         -          Neural
# 131943  TFs and others     Carm1          Neural
# 131981  TFs and others     Hdac1          Neural
# 132048  TFs and others      Phf8          Neural
# 132106  TFs and others         -          Neural
# 132115  TFs and others         -          Neural
# 132146  TFs and others      Rela          Neural
# 132185  TFs and others      Cbx3          Neural
# 132226  TFs and others      Mycn          Neural
# 132227  TFs and others         -          Neural
# 132254  TFs and others    Crebbp          Neural
# 132298  TFs and others         -          Neural
# 132373  TFs and others    Nup153          Neural
# 132412  TFs and others         -          Neural
# 132446  TFs and others         -          Neural
# 132466  TFs and others      Ctcf          Neural
# 132571  TFs and others     Arntl          Neural
# 132635  TFs and others      Rest          Neural
# 132649  TFs and others     Nr2f2          Neural
# 132654  TFs and others         -          Neural
# 132734  TFs and others         -          Neural
# 132775  TFs and others     Foxg1          Neural
# 132828  TFs and others    Crebbp          Neural
# 132832  TFs and others    Dnmt3a          Neural
# 132833  TFs and others      Vsx2          Neural
# 132839  TFs and others      Gfi1          Neural
# 132890  TFs and others      Tcf3          Neural
# 132907  TFs and others         -          Neural
# 132911  TFs and others     Parp1          Neural
# 132932  TFs and others   Mettl14          Neural
# 132991  TFs and others     Cebpa          Neural
# 133020  TFs and others    Dnmt3a          Neural
# 133021  TFs and others     Stat3          Neural
# 133071  TFs and others         -          Neural
# 133077  TFs and others         -          Neural
# 133080  TFs and others     Npas4          Neural
# 133126  TFs and others       Crx          Neural
# 133148  TFs and others      Sox4          Neural
#
#                               cell_type threshold
# 129384                                -        20  \
# 129656                                -        10
# 129864                                -        05
# 129898                                -        50
# 130289                                -        10
# 130351                                -        10
# 130381                                -        05
# 130382                                -        50
# 130385                                -        10
# 130404                  Olfactory Nerve        20
# 130462                                -        20
# 130568                                -        50
# 130613                                -        10
# 130624                                -        10
# 130655                                -        10
# 130659                                -        50
# 130669                                -        50
# 130675                                -        50
# 130704                                -        10
# 130751  Arcuate Nucleus of Hypothalamus        10
# 130795                             Glia        20
# 130814                                -        20
# 130829                                -        50
# 130845  Retinal Rod Photoreceptor Cells        50
# 130909                                -        05
# 130915                                -        20
# 130938  Oligodendrocyte precursor cells        05
# 130987                                -        10
# 131055                         Neuro-2a        20
# 131057                                -        10
# 131063       Induced neural progenitors        10
# 131069                                -        20
# 131070                                -        20
# 131122                                -        10
# 131127                                -        50
# 131163                                -        05
# 131251                                -        05
# 131353                 Striatal neurons        50
# 131357                  Medulloblastoma        50
# 131399                                -        05
# 131405                                -        05
# 131416                                -        20
# 131417       Superior Cervical Ganglion        10
# 131446                                -        50
# 131449                            C17-2        10
# 131470              Hippocampal neurons        05
# 131484                                -        20
# 131516                 Striatal neurons        20
# 131552                                -        05
# 131591                                -        50
# 131622                                -        05
# 131626                   Olfactory Bulb        50
# 131639                                -        50
# 131643                                -        50
# 131676                                -        20
# 131707                                -        05
# 131709                                -        10
# 131740                                -        10
# 131776                                -        05
# 131782                  Medulloblastoma        20
# 131808                                -        05
# 131845                                -        50
# 131936                Neural Stem Cells        10
# 131943                                -        50
# 131981                                -        05
# 132048                                -        10
# 132106  Retinal Rod Photoreceptor Cells        20
# 132115                          Neurons        50
# 132146                                -        10
# 132185                                -        20
# 132226                                -        10
# 132227                  Corpus Striatum        50
# 132254                                -        20
# 132298                         Neuro-2a        50
# 132373                                -        20
# 132412                     Neurofibroma        05
# 132446  Neuroepithelial progenitor cell        20
# 132466                                -        10
# 132571                                -        05
# 132635                                -        20
# 132649                                -        20
# 132654                       Astrocytes        10
# 132734                Nucleus Accumbens        10
# 132775                                -        05
# 132828                                -        05
# 132832                                -        50
# 132833                                -        50
# 132839                                -        20
# 132890                                -        20
# 132907                  Cortical neuron        10
# 132911                                -        05
# 132932                                -        20
# 132991                                -        50
# 133020                                -        10
# 133021                                -        20
# 133071                Cerebellar Vermis        05
# 133077                     Brain cortex        05
# 133080                                -        05
# 133126                                -        05
# 133148                                -        05
#
#                                          experimental_ids
# 129384  SRX661585,SRX5287318,SRX19085827,SRX19085833,S...
# 129656  SRX2463202,SRX661585,SRX2957352,SRX2424693,SRX...
# 129864  SRX2463202,SRX14039259,SRX14039261,SRX10394555...
# 129898  SRX661585,SRX5287318,SRX19085827,SRX19085833,S...
# 130289        SRX3331740,SRX3331743,SRX3331741,SRX3331742
# 130351                                          SRX323573
# 130381                              SRX1743136,SRX1743135
# 130382    SRX10616112,SRX10616116,SRX10616117,SRX10616113
# 130385  SRX7895559,SRX7895558,SRX11929789,SRX11929790,...
# 130404  SRX5287318,SRX3828419,SRX3828418,SRX3828415,SR...
# 130462  SRX2172610,SRX2172616,SRX2172617,SRX2172619,SR...
# 130568                              SRX3083357,SRX3083358
# 130613        SRX3009882,SRX3009885,SRX3009883,SRX3009884
# 130624                                         SRX4802721
# 130655    SRX13166188,SRX13166175,SRX13166187,SRX13166180
# 130659  SRX5126304,SRX6907631,SRX6907645,SRX6907636,SR...
# 130669        SRX5131513,SRX1973346,SRX5131514,SRX1973345
# 130675                SRX11976465,SRX11976464,SRX11976446
# 130704  SRX451626,SRX451627,SRX8474013,SRX8474015,SRX8...
# 130751                              SRX6410184,SRX6410186
# 130795  ERX339065,ERX339060,ERX339050,ERX1125759,ERX11...
# 130814  SRX7895559,SRX7895558,SRX11929789,SRX11929790,...
# 130829  SRX821480,SRX2960250,SRX2960253,SRX2960256,SRX...
# 130845                              SRX3602910,SRX3602911
# 130909  SRX9821435,SRX9821436,SRX9821437,SRX9821439,SR...
# 130915                                        SRX12855023
# 130938                                         SRX8910247
# 130987            SRX018600,SRX018599,SRX018602,SRX018604
# 131055  SRX3661345,SRX3661344,SRX1478415,SRX3837089,SR...
# 131057  SRX3305846,SRX3305844,SRX3305847,SRX3305843,SR...
# 131063                                SRX323573,SRX323564
# 131069        SRX3009883,SRX3009884,SRX3009885,SRX3009882
# 131070                                          SRX019014
# 131122                                         SRX3549422
# 131127  SRX1549454,SRX11123458,SRX11123459,SRX1057041,...
# 131163  SRX5204021,SRX5204018,SRX5204017,SRX5204015,SR...
# 131251                                          SRX150789
# 131353                                         SRX1898479
# 131357  SRX4815872,SRX5131513,SRX821474,SRX821479,SRX8...
# 131399                              SRX7895563,SRX7895562
# 131405  SRX5664989,SRX5664993,SRX5664991,SRX5664992,SR...
# 131416                                        SRX12197061
# 131417                                          SRX435084
# 131446  SRX429086,SRX429082,SRX7098814,SRX7098861,SRX7...
# 131449                      SRX150789,SRX150787,SRX150788
# 131470                                         SRX3171011
# 131484                                          SRX315275
# 131516                                         SRX1898479
# 131552        SRX3009882,SRX3009883,SRX3009885,SRX3009884
# 131591                                         SRX5036628
# 131622                SRX16204199,SRX16204198,SRX16204197
# 131626  SRX7815181,SRX7815189,SRX7815191,SRX7815190,SR...
# 131639  SRX2463202,SRX2182950,SRX2463203,SRX2463205,SR...
# 131643                                SRX671668,SRX671663
# 131676        SRX2869868,SRX4338234,SRX7902429,SRX7902430
# 131707                              SRX2500402,SRX2500401
# 131709                              SRX5185316,SRX5185314
# 131740  SRX12264631,SRX12264627,SRX12264629,SRX1226463...
# 131776  SRX3305843,SRX3305846,SRX3305844,SRX3305847,SR...
# 131782  SRX4815872,SRX821474,SRX5131513,SRX5131516,SRX...
# 131808        SRX1973346,SRX5131513,SRX5131514,SRX1973345
# 131845                              SRX2500401,SRX2500402
# 131936  SRX1094552,SRX3195762,SRX3195761,SRX2254825,SR...
# 131943                                         SRX3549424
# 131981       SRX13844084,SRX4178833,SRX4178834,SRX4178832
# 132048                                         SRX7366387
# 132106                              SRX3602910,SRX3602911
# 132115  SRX032491,SRX12264631,SRX12264595,SRX12264593,...
# 132146                            SRX11973756,SRX11973758
# 132185        SRX4922913,SRX4922914,SRX4922915,SRX4922912
# 132226  SRX821480,SRX2960250,SRX821477,SRX2960253,SRX2...
# 132227  SRX8357832,SRX8357810,SRX8357811,SRX8357834,SR...
# 132254  SRX6095468,SRX6095461,SRX6095462,SRX6095463,SR...
# 132298  SRX3661345,SRX3661344,SRX1478415,SRX3837089,SR...
# 132373                                         SRX2892883
# 132412                                         SRX5036628
# 132446  SRX2955826,SRX2955818,SRX2955825,SRX2955819,SR...
# 132466  SRX661585,SRX2424693,SRX2424694,SRX2423531,SRX...
# 132571    SRX15951259,SRX15951260,SRX15951261,SRX15951262
# 132635  SRX13924408,SRX13924409,SRX13924407,SRX1392440...
# 132649                                        SRX19820323
# 132654  SRX109474,SRX326212,SRX14203722,SRX10488747,SR...
# 132734  SRX472713,SRX445339,SRX445337,SRX472712,SRX445...
# 132775    SRX13166188,SRX13166187,SRX13166175,SRX13166180
# 132828  SRX6095461,SRX6095468,SRX6095462,SRX6095463,SR...
# 132832  SRX3242121,SRX3242165,SRX3242109,SRX3242112,SR...
# 132833  SRX14039255,SRX14039257,SRX14039259,SRX1039455...
# 132839        SRX5131513,SRX1973346,SRX5131514,SRX1973345
# 132890  SRX3195761,SRX2254825,SRX3195762,SRX3195763,SR...
# 132907  SRX5509062,SRX5509061,SRX9821435,SRX9821436,SR...
# 132911                                SRX472713,SRX472712
# 132932                             SRX7644326,SRX14138498
# 132991                      SRX451623,SRX451622,SRX451624
# 133020  SRX3242117,SRX3242115,SRX3242168,SRX3242112,SR...
# 133021  SRX2182963,SRX2463209,SRX2885380,SRX2885381,SR...
# 133071  SRX5491876,SRX5491880,SRX5491875,SRX5491879,SR...
# 133077  SRX062939,SRX2384333,SRX2384329,SRX2384337,SRX...
# 133080                            SRX17984809,SRX17984810
# 133126            SRX018599,SRX018600,SRX018604,SRX018602
# 133148                                         SRX4802721

# %%
#subset again to get all the peaks with a threshold of 05 - this is more relaxed then the other thresholds
peak_files_mm10_TFs_05 = peak_files_mm10_TFs[peak_files_mm10_TFs['file_name'].str.contains('05')]
print(len(peak_files_mm10_TFs_05))
# Out:
# 3578

# %%
# get a list of the all filenames for the factors and all their peaks for all tissues 
files_for_download = peak_files_mm10_TFs_05[(peak_files_mm10_TFs_05['cell_type_class']=='All cell types') & (peak_files_mm10_TFs_05['antigen'] != '-')]['file_name'].unique()

# %%
print(files_for_download)
# Out:
# ['Oth.ALL.05.Foxo1.AllCell' 'Oth.ALL.05.Gtf2f1.AllCell'
#  'Oth.ALL.05.Ddx21.AllCell' 'Oth.ALL.05.Sp9.AllCell'
#  'Oth.ALL.05.Nfkb1.AllCell' 'Oth.ALL.05.E4f1.AllCell'
#  'Oth.ALL.05.Taf7l.AllCell' 'Oth.ALL.05.Foxa2.AllCell'
#  'Oth.ALL.05.Pcgf1.AllCell' 'Oth.ALL.05.Nbn.AllCell'
#  'Oth.ALL.05.Arid1b.AllCell' 'Oth.ALL.05.Matr3.AllCell'
#  'Oth.ALL.05.Bcl11b.AllCell' 'Oth.ALL.05.Tnni2.AllCell'
#  'Oth.ALL.05.Ctbp2.AllCell' 'Oth.ALL.05.Taf9b.AllCell'
#  'Oth.ALL.05.Srsf1.AllCell' 'Oth.ALL.05.Creb3l2.AllCell'
#  'Oth.ALL.05.0610010K14Rik.AllCell' 'Oth.ALL.05.Gcm1.AllCell'
#  'Oth.ALL.05.Cbx4.AllCell' 'Oth.ALL.05.Wtap.AllCell'
#  'Oth.ALL.05.Mybl1.AllCell' 'Oth.ALL.05.Prdm15.AllCell'
#  'Oth.ALL.05.Cdx2.AllCell' 'Oth.ALL.05.Hdac2.AllCell'
#  'Oth.ALL.05.Cbfa2t3.AllCell' 'Oth.ALL.05.Sox2.AllCell'
#  'Oth.ALL.05.Kmt2c.AllCell' 'Oth.ALL.05.Ebf4.AllCell'
#  'Oth.ALL.05.DNA-RNA_hybrid.AllCell' 'Oth.ALL.05.Lin9.AllCell'
#  'Oth.ALL.05.AML1-ETO.AllCell' 'Oth.ALL.05.Dmap1.AllCell'
#  'Oth.ALL.05.Tbx3.AllCell' 'Oth.ALL.05.Irf3.AllCell'
#  'Oth.ALL.05.Etv5.AllCell' 'Oth.ALL.05.Nelfa.AllCell'
#  'Oth.ALL.05.Dmc1.AllCell' 'Oth.ALL.05.Elk4.AllCell'
#  'Oth.ALL.05.Irf7.AllCell' 'Oth.ALL.05.Prmt5.AllCell'
#  'Oth.ALL.05.Zic2.AllCell' 'Oth.ALL.05.Utf1.AllCell'
#  'Oth.ALL.05.Chd1.AllCell' 'Oth.ALL.05.Wdr61.AllCell'
#  'Oth.ALL.05.Sox4.AllCell' 'Oth.ALL.05.Stra8.AllCell'
#  'Oth.ALL.05.Zc3h10.AllCell' 'Oth.ALL.05.Acaa2.AllCell'
#  'Oth.ALL.05.Bmi1.AllCell' 'Oth.ALL.05.Dhx9.AllCell'
#  'Oth.ALL.05.Nfe2.AllCell' 'Oth.ALL.05.Zc3h11a.AllCell'
#  'Oth.ALL.05.Six4.AllCell' 'Oth.ALL.05.Stag1.AllCell'
#  'Oth.ALL.05.Pgr.AllCell' 'Oth.ALL.05.Hcfc1.AllCell'
#  'Oth.ALL.05.Zbtb2.AllCell' 'Oth.ALL.05.Phf8.AllCell'
#  'Oth.ALL.05.Mef2a.AllCell' 'Oth.ALL.05.Ddx1.AllCell'
#  'Oth.ALL.05.Nup107.AllCell' 'Oth.ALL.05.Ago2.AllCell'
#  'Oth.ALL.05.Pawr.AllCell' 'Oth.ALL.05.Foxh1.AllCell'
#  'Oth.ALL.05.Foxk2.AllCell' 'Oth.ALL.05.Pou3f2.AllCell'
#  'Oth.ALL.05.Rb1.AllCell' 'Oth.ALL.05.Mef2c.AllCell'
#  'Oth.ALL.05.Hoxd9.AllCell' 'Oth.ALL.05.Foxp3.AllCell'
#  'Oth.ALL.05.Ehmt2.AllCell' 'Oth.ALL.05.Lmx1b.AllCell'
#  'Oth.ALL.05.Ptbp1.AllCell' 'Oth.ALL.05.Foxg1.AllCell'
#  'Oth.ALL.05.Nfe2l2.AllCell' 'Oth.ALL.05.Btaf1.AllCell'
#  'Oth.ALL.05.Hopx.AllCell' 'Oth.ALL.05.H1foo.AllCell'
#  'Oth.ALL.05.Ikzf1.AllCell' 'Oth.ALL.05.Nlrc5.AllCell'
#  'Oth.ALL.05.Prm1.AllCell' 'Oth.ALL.05.Dr1.AllCell'
#  'Oth.ALL.05.Dpf3.AllCell' 'Oth.ALL.05.Hmga2.AllCell'
#  'Oth.ALL.05.Cebpb.AllCell' 'Oth.ALL.05.Terf2ip.AllCell'
#  'Oth.ALL.05.Otx2.AllCell' 'Oth.ALL.05.Trp53.AllCell'
#  'Oth.ALL.05.Pbrm1.AllCell' 'Oth.ALL.05.Bcor.AllCell'
#  'Oth.ALL.05.Wdr11.AllCell' 'Oth.ALL.05.Setd5.AllCell'
#  'Oth.ALL.05.Prdm9.AllCell' 'Oth.ALL.05.Sirt7.AllCell'
#  'Oth.ALL.05.Ell3.AllCell' 'Oth.ALL.05.Mtor.AllCell'
#  'Oth.ALL.05.Cebpd.AllCell' 'Oth.ALL.05.Gtf3c1.AllCell'
#  'Oth.ALL.05.Mettl14.AllCell' 'Oth.ALL.05.Nacc1.AllCell'
#  'Oth.ALL.05.Pou2af1.AllCell' 'Oth.ALL.05.Cux2.AllCell'
#  'Oth.ALL.05.Zc3h4.AllCell' 'Oth.ALL.05.Nr1d1.AllCell'
#  'Oth.ALL.05.Foxk1.AllCell' 'Oth.ALL.05.Nr1i2.AllCell'
#  'Oth.ALL.05.Ncoa3.AllCell' 'Oth.ALL.05.Arid1a.AllCell'
#  'Oth.ALL.05.Nfix.AllCell' 'Oth.ALL.05.Bhlhe41.AllCell'
#  'Oth.ALL.05.Ino80.AllCell' 'Oth.ALL.05.Pbx1.AllCell'
#  'Oth.ALL.05.Terf1.AllCell' 'Oth.ALL.05.Dnttip1.AllCell'
#  'Oth.ALL.05.Zbtb7b.AllCell' 'Oth.ALL.05.Foxa3.AllCell'
#  'Oth.ALL.05.Zfp281.AllCell' 'Oth.ALL.05.Ybx1.AllCell'
#  'Oth.ALL.05.Lhx2.AllCell' 'Oth.ALL.05.Nkx2-5.AllCell'
#  'Oth.ALL.05.Kmt2b.AllCell' 'Oth.ALL.05.Kdm3b.AllCell'
#  'Oth.ALL.05.Ep300.AllCell' 'Oth.ALL.05.Klf15.AllCell'
#  'Oth.ALL.05.Succinyllysine.AllCell' 'Oth.ALL.05.Batf3.AllCell'
#  'Oth.ALL.05.Lhx6.AllCell' 'Oth.ALL.05.Rela.AllCell'
#  'Oth.ALL.05.Sox15.AllCell' 'Oth.ALL.05.Prrx1.AllCell'
#  'Oth.ALL.05.Ddx5.AllCell' 'Oth.ALL.05.Raf1.AllCell'
#  'Oth.ALL.05.Phf20.AllCell' 'Oth.ALL.05.Ncl.AllCell'
#  'Oth.ALL.05.Lef1.AllCell' 'Oth.ALL.05.Nlrp3.AllCell'
#  'Oth.ALL.05.Daxx.AllCell' 'Oth.ALL.05.Ncaph2.AllCell'
#  'Oth.ALL.05.Tbx5.AllCell' 'Oth.ALL.05.Top2b.AllCell'
#  'Oth.ALL.05.Prdm1.AllCell' 'Oth.ALL.05.Acss2.AllCell'
#  'Oth.ALL.05.E2f6.AllCell' 'Oth.ALL.05.Tmem131.AllCell'
#  'Oth.ALL.05.Kdm5c.AllCell' 'Oth.ALL.05.Trp63.AllCell'
#  'Oth.ALL.05.Atm.AllCell' 'Oth.ALL.05.Fbxo21.AllCell'
#  'Oth.ALL.05.Hoxa13.AllCell' 'Oth.ALL.05.Ddx18.AllCell'
#  'Oth.ALL.05.Cebpa.AllCell' 'Oth.ALL.05.Kmt2d.AllCell'
#  'Oth.ALL.05.Tbpl1.AllCell' 'Oth.ALL.05.Sirt6.AllCell'
#  'Oth.ALL.05.O-GlcNAc.AllCell' 'Oth.ALL.05.Heyl.AllCell'
#  'Oth.ALL.05.Ythdc1.AllCell' 'Oth.ALL.05.Rfx1.AllCell'
#  'Oth.ALL.05.Hsf2.AllCell' 'Oth.ALL.05.Dmrtb1.AllCell'
#  'Oth.ALL.05.Dpy30.AllCell' 'Oth.ALL.05.Hnf1b.AllCell'
#  'Oth.ALL.05.Samd7.AllCell' 'Oth.ALL.05.Dmrt1.AllCell'
#  'Oth.ALL.05.Xbp1.AllCell' 'Oth.ALL.05.Nr1h3.AllCell'
#  'Oth.ALL.05.Smc1a.AllCell' 'Oth.ALL.05.Zfp64.AllCell'
#  'Oth.ALL.05.Tle1.AllCell' 'Oth.ALL.05.Uhrf1.AllCell'
#  'Oth.ALL.05.Nr1d2.AllCell' 'Oth.ALL.05.Eomes.AllCell'
#  'Oth.ALL.05.Ncor1.AllCell' 'Oth.ALL.05.Tle3.AllCell'
#  'Oth.ALL.05.Supt5.AllCell' 'Oth.ALL.05.Rec8.AllCell'
#  'Oth.ALL.05.Nucks1.AllCell' 'Oth.ALL.05.Esrra.AllCell'
#  'Oth.ALL.05.Mlxipl.AllCell' 'Oth.ALL.05.Pygo2.AllCell'
#  'Oth.ALL.05.Smarcb1.AllCell' 'Oth.ALL.05.Dnmt3a.AllCell'
#  'Oth.ALL.05.GFP.AllCell' 'Oth.ALL.05.Neurod2.AllCell'
#  'Oth.ALL.05.Ascl2.AllCell' 'Oth.ALL.05.Pou5f1.AllCell'
#  'Oth.ALL.05.Prdm13.AllCell' 'Oth.ALL.05.Nipbl.AllCell'
#  'Oth.ALL.05.Rbbp7.AllCell' 'Oth.ALL.05.Zeb1.AllCell'
#  'Oth.ALL.05.Hdac1.AllCell' 'Oth.ALL.05.Safb2.AllCell'
#  'Oth.ALL.05.Fosl2.AllCell' 'Oth.ALL.05.Prdm5.AllCell'
#  'Oth.ALL.05.Wdr5.AllCell' 'Oth.ALL.05.Tfe3.AllCell'
#  'Oth.ALL.05.Cbx2.AllCell' 'Oth.ALL.05.Tfap2a.AllCell'
#  'Oth.ALL.05.HBx.AllCell' 'Oth.ALL.05.Ccnk.AllCell'
#  'Oth.ALL.05.Tmpo.AllCell' 'Oth.ALL.05.Smyd2.AllCell'
#  'Oth.ALL.05.Rel.AllCell' 'Oth.ALL.05.Polr1a.AllCell'
#  'Oth.ALL.05.Mta1.AllCell' 'Oth.ALL.05.Cdk9.AllCell'
#  'Oth.ALL.05.Sall1.AllCell' 'Oth.ALL.05.Hexim1.AllCell'
#  'Oth.ALL.05.Carm1.AllCell' 'Oth.ALL.05.Psip1.AllCell'
#  'Oth.ALL.05.Kdm4b.AllCell' 'Oth.ALL.05.Was.AllCell'
#  'Oth.ALL.05.Bhlhe40.AllCell' 'Oth.ALL.05.Zfp217.AllCell'
#  'Oth.ALL.05.Hnrnpk.AllCell' 'Oth.ALL.05.Gsk3b.AllCell'
#  'Oth.ALL.05.Nkx2-1.AllCell' 'Oth.ALL.05.Sfmbt1.AllCell'
#  'Oth.ALL.05.Nr1h2.AllCell' 'Oth.ALL.05.Tcf7l1.AllCell'
#  'Oth.ALL.05.Setd2.AllCell' 'Oth.ALL.05.Jund.AllCell'
#  'Oth.ALL.05.Mpnd.AllCell' 'Oth.ALL.05.Sox10.AllCell'
#  'Oth.ALL.05.Sp7.AllCell' 'Oth.ALL.05.Smarca2.AllCell'
#  'Oth.ALL.05.Suv39h2.AllCell' 'Oth.ALL.05.Atf2.AllCell'
#  'Oth.ALL.05.Zic3.AllCell' 'Oth.ALL.05.Med1.AllCell'
#  'Oth.ALL.05.Zkscan1.AllCell' 'Oth.ALL.05.Rorc.AllCell'
#  'Oth.ALL.05.Stab1.AllCell' 'Oth.ALL.05.Bcl6.AllCell'
#  'Oth.ALL.05.Gad1.AllCell' 'Oth.ALL.05.Pcgf2.AllCell'
#  'Oth.ALL.05.Safb.AllCell' 'Oth.ALL.05.Klf5.AllCell'
#  'Oth.ALL.05.Myc.AllCell' 'Oth.ALL.05.Etv6.AllCell'
#  'Oth.ALL.05.Tcf3.AllCell' 'Oth.ALL.05.Hdac5.AllCell'
#  'Oth.ALL.05.Sp110.AllCell' 'Oth.ALL.05.Lysin_homocysteine.AllCell'
#  'Oth.ALL.05.Nr4a1.AllCell' 'Oth.ALL.05.Fev.AllCell'
#  'Oth.ALL.05.Trim24.AllCell' 'Oth.ALL.05.Hnrnpl.AllCell'
#  'Oth.ALL.05.Rora.AllCell' 'Oth.ALL.05.Ikzf2.AllCell'
#  'Oth.ALL.05.Tlx1.AllCell' 'Oth.ALL.05.Stat3.AllCell'
#  'Oth.ALL.05.Baz1a.AllCell' 'Oth.ALL.05.Crebbp.AllCell'
#  'Oth.ALL.05.Maff.AllCell' 'Oth.ALL.05.Hdac7.AllCell'
#  'Oth.ALL.05.Suz12.AllCell' 'Oth.ALL.05.Ptf1a.AllCell'
#  'Oth.ALL.05.Esrrg.AllCell' 'Oth.ALL.05.Relb.AllCell'
#  'Oth.ALL.05.Tcf12.AllCell' 'Oth.ALL.05.Rag1.AllCell'
#  'Oth.ALL.05.Sfmbt2.AllCell' 'Oth.ALL.05.Aff3.AllCell'
#  'Oth.ALL.05.Nfatc1.AllCell' 'Oth.ALL.05.Egr2.AllCell'
#  'Oth.ALL.05.Foxp1.AllCell' 'Oth.ALL.05.Kat7.AllCell'
#  'Oth.ALL.05.Hira.AllCell' 'Oth.ALL.05.Cirh1a.AllCell'
#  'Oth.ALL.05.Scml2.AllCell' 'Oth.ALL.05.Brd3.AllCell'
#  'Oth.ALL.05.Brca1.AllCell' 'Oth.ALL.05.Prdm14.AllCell'
#  'Oth.ALL.05.Hmgn2.AllCell' 'Oth.ALL.05.Phf2.AllCell'
#  'Oth.ALL.05.Kmt2a.AllCell' 'Oth.ALL.05.Ets1.AllCell'
#  'Oth.ALL.05.Dgcr8.AllCell' 'Oth.ALL.05.Pml.AllCell'
#  'Oth.ALL.05.Sumo1.AllCell' 'Oth.ALL.05.Lmnb1.AllCell'
#  'Oth.ALL.05.Supt6.AllCell' 'Oth.ALL.05.Nfya.AllCell'
#  'Oth.ALL.05.Zfp961.AllCell' 'Oth.ALL.05.Twist1.AllCell'
#  'Oth.ALL.05.Nr5a1.AllCell' 'Oth.ALL.05.Smad3.AllCell'
#  'Oth.ALL.05.Sp6.AllCell' 'Oth.ALL.05.Rnf20.AllCell'
#  'Oth.ALL.05.Neurod1.AllCell' 'Oth.ALL.05.Zfpm1.AllCell'
#  'Oth.ALL.05.Top1.AllCell' 'Oth.ALL.05.Lhx3.AllCell'
#  'Oth.ALL.05.Ruvbl1.AllCell' 'Oth.ALL.05.Cbx3.AllCell'
#  'Oth.ALL.05.Cdk7.AllCell' 'Oth.ALL.05.Phf6.AllCell'
#  'Oth.ALL.05.Dpf2.AllCell' 'Oth.ALL.05.Satb1.AllCell'
#  'Oth.ALL.05.Brdt.AllCell' 'Oth.ALL.05.Fo.AllCell'
#  'Oth.ALL.05.Mettl3.AllCell' 'Oth.ALL.05.Atf7.AllCell'
#  'Oth.ALL.05.Aebp2.AllCell' 'Oth.ALL.05.Naca.AllCell'
#  'Oth.ALL.05.Cas9.AllCell' 'Oth.ALL.05.Rara.AllCell'
#  'Oth.ALL.05.Hif1a.AllCell' 'Oth.ALL.05.Baz2a.AllCell'
#  'Oth.ALL.05.Tcf7l2.AllCell' 'Oth.ALL.05.Zmynd11.AllCell'
#  'Oth.ALL.05.Hoxc10.AllCell' 'Oth.ALL.05.Aff4.AllCell'
#  'Oth.ALL.05.Bnc1.AllCell' 'Oth.ALL.05.Jun.AllCell'
#  'Oth.ALL.05.Hand1.AllCell' 'Oth.ALL.05.Nkx3-1.AllCell'
#  'Oth.ALL.05.Ascl1.AllCell' 'Oth.ALL.05.Lyl1.AllCell'
#  'Oth.ALL.05.Msh6.AllCell' 'Oth.ALL.05.Utp3.AllCell'
#  'Oth.ALL.05.Pagr1a.AllCell' 'Oth.ALL.05.Stat2.AllCell'
#  'Oth.ALL.05.Hoxc6.AllCell' 'Oth.ALL.05.Fam60a.AllCell'
#  'Oth.ALL.05.Tbx4.AllCell' 'Oth.ALL.05.Hes1.AllCell'
#  'Oth.ALL.05.Dppa4.AllCell' 'Oth.ALL.05.Ogt.AllCell'
#  'Oth.ALL.05.Smarca4.AllCell' 'Oth.ALL.05.Gata4.AllCell'
#  'Oth.ALL.05.Spen.AllCell' 'Oth.ALL.05.Usp16.AllCell'
#  'Oth.ALL.05.Ncoa2.AllCell' 'Oth.ALL.05.Trps1.AllCell'
#  'Oth.ALL.05.Insm1.AllCell' 'Oth.ALL.05.Usf2.AllCell'
#  'Oth.ALL.05.Zbtb17.AllCell' 'Oth.ALL.05.Phrf1.AllCell'
#  'Oth.ALL.05.Gfi1.AllCell' 'Oth.ALL.05.Chd8.AllCell'
#  'Oth.ALL.05.Foxo3.AllCell' 'Oth.ALL.05.Irf4.AllCell'
#  'Oth.ALL.05.Ell.AllCell' 'Oth.ALL.05.Pknox1.AllCell'
#  'Oth.ALL.05.Ehf.AllCell' 'Oth.ALL.05.Bcl11a.AllCell'
#  'Oth.ALL.05.Zscan5b.AllCell' 'Oth.ALL.05.Tgif2.AllCell'
#  'Oth.ALL.05.Hnrnpu.AllCell' 'Oth.ALL.05.Pitx1.AllCell'
#  'Oth.ALL.05.Wdr82.AllCell' 'Oth.ALL.05.Six2.AllCell'
#  'Oth.ALL.05.Usp7.AllCell' 'Oth.ALL.05.Zfp191.AllCell'
#  'Oth.ALL.05.Uhrf2.AllCell' 'Oth.ALL.05.Ssu72.AllCell'
#  'Oth.ALL.05.Naa10.AllCell' 'Oth.ALL.05.Cxxc1.AllCell'
#  'Oth.ALL.05.Cbx7.AllCell' 'Oth.ALL.05.Meis1.AllCell'
#  'Oth.ALL.05.Dendra2.AllCell' 'Oth.ALL.05.Rxra.AllCell'
#  'Oth.ALL.05.Hdac4.AllCell' 'Oth.ALL.05.Pax8.AllCell'
#  'Oth.ALL.05.Mkl1.AllCell' 'Oth.ALL.05.Sox6.AllCell'
#  'Oth.ALL.05.Tet1.AllCell' 'Oth.ALL.05.Srebf1.AllCell'
#  'Oth.ALL.05.Klf9.AllCell' 'Oth.ALL.05.N6amt1.AllCell'
#  'Oth.ALL.05.Gata6.AllCell' 'Oth.ALL.05.Ddit3.AllCell'
#  'Oth.ALL.05.Klf6.AllCell' 'Oth.ALL.05.Sox5.AllCell'
#  'Oth.ALL.05.Usp22.AllCell' 'Oth.ALL.05.Npas3.AllCell'
#  'Oth.ALL.05.Hand2.AllCell' 'Oth.ALL.05.Chd2.AllCell'
#  'Oth.ALL.05.Bach2.AllCell' 'Oth.ALL.05.Ppara.AllCell'
#  'Oth.ALL.05.Tox.AllCell' 'Oth.ALL.05.Pcgf5.AllCell'
#  'Oth.ALL.05.Hnf1a.AllCell' 'Oth.ALL.05.Phf10.AllCell'
#  'Oth.ALL.05.Nup153.AllCell' 'Oth.ALL.05.L3mbtl3.AllCell'
#  'Oth.ALL.05.Tcf4.AllCell' 'Oth.ALL.05.Gtf2e2.AllCell'
#  'Oth.ALL.05.Ahcy.AllCell' 'Oth.ALL.05.Yap1.AllCell'
#  'Oth.ALL.05.Pds5b.AllCell' 'Oth.ALL.05.Max.AllCell'
#  'Oth.ALL.05.Nr5a2.AllCell' 'Oth.ALL.05.Maf.AllCell'
#  'Oth.ALL.05.BrdU.AllCell' 'Oth.ALL.05.Nfia.AllCell'
#  'Oth.ALL.05.Srf.AllCell' 'Oth.ALL.05.Tfap2c.AllCell'
#  'Oth.ALL.05.Mapk8.AllCell' 'Oth.ALL.05.Rybp.AllCell'
#  'Oth.ALL.05.Rad21.AllCell' 'Oth.ALL.05.Plagl1.AllCell'
#  'Oth.ALL.05.Spib.AllCell' 'Oth.ALL.05.Arid2.AllCell'
#  'Oth.ALL.05.Trmt112.AllCell' 'Oth.ALL.05.Ell2.AllCell'
#  'Oth.ALL.05.E2f1.AllCell' 'Oth.ALL.05.Phc2.AllCell'
#  'Oth.ALL.05.ADP-ribose.AllCell' 'Oth.ALL.05.Gtf2b.AllCell'
#  'Oth.ALL.05.Vsx2.AllCell' 'Oth.ALL.05.Arid5a.AllCell'
#  'Oth.ALL.05.Wiz.AllCell' 'Oth.ALL.05.Stat5b.AllCell'
#  'Oth.ALL.05.Ahr.AllCell' 'Oth.ALL.05.Mre11a.AllCell'
#  'Oth.ALL.05.Elf1.AllCell' 'Oth.ALL.05.Mnx1.AllCell'
#  'Oth.ALL.05.Pspc1.AllCell' 'Oth.ALL.05.Taf10.AllCell'
#  'Oth.ALL.05.Tbl1x.AllCell' 'Oth.ALL.05.Sp3.AllCell'
#  'Oth.ALL.05.Satb2.AllCell' 'Oth.ALL.05.Sap18.AllCell'
#  'Oth.ALL.05.Sap130.AllCell' 'Oth.ALL.05.Gli1.AllCell'
#  'Oth.ALL.05.Hdgf2.AllCell' 'Oth.ALL.05.Batf.AllCell'
#  'Oth.ALL.05.Stat1.AllCell' 'Oth.ALL.05.Sin3a.AllCell'
#  'Oth.ALL.05.Junb.AllCell' 'Oth.ALL.05.Arid3a.AllCell'
#  'Oth.ALL.05.Tcf7.AllCell' 'Oth.ALL.05.Npm1.AllCell'
#  'Oth.ALL.05.Raly.AllCell' 'Oth.ALL.05.Sirt1.AllCell'
#  'Oth.ALL.05.Qk.AllCell' 'Oth.ALL.05.Tfcp2l1.AllCell'
#  'Oth.ALL.05.Esrrb.AllCell' 'Oth.ALL.05.Kdm2b.AllCell'
#  'Oth.ALL.05.Nfat5.AllCell' 'Oth.ALL.05.Nfib.AllCell'
#  'Oth.ALL.05.Tfap4.AllCell' 'Oth.ALL.05.Zfp322a.AllCell'
#  'Oth.ALL.05.Mycn.AllCell' 'Oth.ALL.05.Cebpg.AllCell'
#  'Oth.ALL.05.Hsf1.AllCell' 'Oth.ALL.05.Foxl2.AllCell'
#  'Oth.ALL.05.Chuk.AllCell' 'Oth.ALL.05.Nfil3.AllCell'
#  'Oth.ALL.05.Mxi1.AllCell' 'Oth.ALL.05.Ets2.AllCell'
#  'Oth.ALL.05.Nkx2-2.AllCell' 'Oth.ALL.05.Elf4.AllCell'
#  'Oth.ALL.05.Zbtb11.AllCell' 'Oth.ALL.05.Hoxc9.AllCell'
#  'Oth.ALL.05.Brca2.AllCell' 'Oth.ALL.05.Ss18.AllCell'
#  'Oth.ALL.05.Glis3.AllCell' 'Oth.ALL.05.Tcfl5.AllCell'
#  'Oth.ALL.05.Prox1.AllCell' 'Oth.ALL.05.Mllt3.AllCell'
#  'Oth.ALL.05.Dicer1.AllCell' 'Oth.ALL.05.Myo1c.AllCell'
#  'Oth.ALL.05.Mysm1.AllCell' 'Oth.ALL.05.Wt1.AllCell'
#  'Oth.ALL.05.Jmjd1c.AllCell' 'Oth.ALL.05.Supt4a.AllCell'
#  'Oth.ALL.05.Cd38.AllCell' 'Oth.ALL.05.Ovol1.AllCell'
#  'Oth.ALL.05.Smchd1.AllCell' 'Oth.ALL.05.Crtc2.AllCell'
#  'Oth.ALL.05.Atrx.AllCell' 'Oth.ALL.05.Whsc1l1.AllCell'
#  'Oth.ALL.05.Med23.AllCell' 'Oth.ALL.05.Mafg.AllCell'
#  'Oth.ALL.05.Nfyc.AllCell' 'Oth.ALL.05.RFP.AllCell'
#  'Oth.ALL.05.Clock.AllCell' 'Oth.ALL.05.Pds5a.AllCell'
#  'Oth.ALL.05.Esr1.AllCell' 'Oth.ALL.05.Atf4.AllCell'
#  'Oth.ALL.05.Crtc3.AllCell' 'Oth.ALL.05.Brd4.AllCell'
#  'Oth.ALL.05.Zic1.AllCell' 'Oth.ALL.05.Zfp57.AllCell'
#  'Oth.ALL.05.Leo1.AllCell' 'Oth.ALL.05.Hdgfrp2.AllCell'
#  'Oth.ALL.05.Dppa2.AllCell' 'Oth.ALL.05.Nelfb.AllCell'
#  'Oth.ALL.05.Pax7.AllCell' 'Oth.ALL.05.Ash2l.AllCell'
#  'Oth.ALL.05.Foxa1.AllCell' 'Oth.ALL.05.Taf1.AllCell'
#  'Oth.ALL.05.Cdk8.AllCell' 'Oth.ALL.05.Med4.AllCell'
#  'Oth.ALL.05.Tet2.AllCell' 'Oth.ALL.05.Tet3.AllCell'
#  'Oth.ALL.05.Bap1.AllCell' 'Oth.ALL.05.Runx3.AllCell'
#  'Oth.ALL.05.Emx2.AllCell' 'Oth.ALL.05.Cbfa2t2.AllCell'
#  'Oth.ALL.05.Snai1.AllCell' 'Oth.ALL.05.Epop.AllCell'
#  'Oth.ALL.05.Mbd3.AllCell' 'Oth.ALL.05.Ncapd3.AllCell'
#  'Oth.ALL.05.Shox2.AllCell' 'Oth.ALL.05.Eed.AllCell'
#  'Oth.ALL.05.Arntl.AllCell' 'Oth.ALL.05.Kdm3a.AllCell'
#  'Oth.ALL.05.Rag2.AllCell' 'Oth.ALL.05.CEBPA.AllCell'
#  'Oth.ALL.05.Ar.AllCell' 'Oth.ALL.05.Prdm16.AllCell'
#  'Oth.ALL.05.Zmiz1.AllCell' 'Oth.ALL.05.Kdm6b.AllCell'
#  'Oth.ALL.05.Sox11.AllCell' 'Oth.ALL.05.Taf12.AllCell'
#  'Oth.ALL.05.Smad1.AllCell' 'Oth.ALL.05.E2f3.AllCell'
#  'Oth.ALL.05.Lmo2.AllCell' 'Oth.ALL.05.Zbtb24.AllCell'
#  'Oth.ALL.05.Ovol2.AllCell' 'Oth.ALL.05.Pcgf3.AllCell'
#  'Oth.ALL.05.Mecp2.AllCell' 'Oth.ALL.05.Dnmt3l.AllCell'
#  'Oth.ALL.05.Notch1.AllCell' 'Oth.ALL.05.Mllt10.AllCell'
#  'Oth.ALL.05.Dlx3.AllCell' 'Oth.ALL.05.Gmnn.AllCell'
#  'Oth.ALL.05.Yy1.AllCell' 'Oth.ALL.05.Myog.AllCell'
#  'Oth.ALL.05.Irf2.AllCell' 'Oth.ALL.05.Six1.AllCell'
#  'Oth.ALL.05.Nelfe.AllCell' 'Oth.ALL.05.Rcor2.AllCell'
#  'Oth.ALL.05.Nanog.AllCell' 'Oth.ALL.05.Kdm4d.AllCell'
#  'Oth.ALL.05.Alkbh5.AllCell' 'Oth.ALL.05.Zfp708.AllCell'
#  'Oth.ALL.05.Dnajc2.AllCell' 'Oth.ALL.05.Brd7.AllCell'
#  'Oth.ALL.05.Phf5a.AllCell' 'Oth.ALL.05.Taf15.AllCell'
#  'Oth.ALL.05.Pwp1.AllCell' 'Oth.ALL.05.Klf4.AllCell'
#  'Oth.ALL.05.Ttf1.AllCell' 'Oth.ALL.05.Chaf1b.AllCell'
#  'Oth.ALL.05.Creb1.AllCell' 'Oth.ALL.05.Med14.AllCell'
#  'Oth.ALL.05.Sox30.AllCell' 'Oth.ALL.05.Butyryllysine.AllCell'
#  'Oth.ALL.05.Rarb.AllCell' 'Oth.ALL.05.Cebpe.AllCell'
#  'Oth.ALL.05.Hnrnpul1.AllCell' 'Oth.ALL.05.Ncapg.AllCell'
#  'Oth.ALL.05.Park7.AllCell' 'Oth.ALL.05.Paf1.AllCell'
#  'Oth.ALL.05.Ctr9.AllCell' 'Oth.ALL.05.Med24.AllCell'
#  'Oth.ALL.05.Grhl3.AllCell' 'Oth.ALL.05.Tead4.AllCell'
#  'Oth.ALL.05.Sumo2.AllCell' 'Oth.ALL.05.Fgfr1.AllCell'
#  'Oth.ALL.05.Prdm10.AllCell' 'Oth.ALL.05.Rpa2.AllCell'
#  'Oth.ALL.05.Isl1.AllCell' 'Oth.ALL.05.Foxc1.AllCell'
#  'Oth.ALL.05.Kat2b.AllCell' 'Oth.ALL.05.Gabpa.AllCell'
#  'Oth.ALL.05.Atf7ip.AllCell' 'Oth.ALL.05.Myb.AllCell'
#  'Oth.ALL.05.Dbp.AllCell' 'Oth.ALL.05.Morc3.AllCell'
#  'Oth.ALL.05.Foxp2.AllCell' 'Oth.ALL.05.Meiosin.AllCell'
#  'Oth.ALL.05.Runx2.AllCell' 'Oth.ALL.05.Rfx3.AllCell'
#  'Oth.ALL.05.Ercc3.AllCell' 'Oth.ALL.05.Gli2.AllCell'
#  'Oth.ALL.05.Onecut2.AllCell' 'Oth.ALL.05.Chd4.AllCell'
#  'Oth.ALL.05.Nup98.AllCell' 'Oth.ALL.05.Glyr1.AllCell'
#  'Oth.ALL.05.Setdb1.AllCell' 'Oth.ALL.05.Nfatc2.AllCell'
#  'Oth.ALL.05.Rbpj.AllCell' 'Oth.ALL.05.Fosb.AllCell'
#  'Oth.ALL.05.Elf5.AllCell' 'Oth.ALL.05.Smad4.AllCell'
#  'Oth.ALL.05.Kdm5a.AllCell' 'Oth.ALL.05.Hoxb1.AllCell'
#  'Oth.ALL.05.Smarcc1.AllCell' 'Oth.ALL.05.8-Hydroxydeoxyguanosine.AllCell'
#  'Oth.ALL.05.Smad6.AllCell' 'Oth.ALL.05.Rbp2.AllCell'
#  'Oth.ALL.05.Irf2bp2.AllCell' 'Oth.ALL.05.Smad7.AllCell'
#  'Oth.ALL.05.Propionyllysine.AllCell' 'Oth.ALL.05.Tfeb.AllCell'
#  'Oth.ALL.05.Nkx3-2.AllCell' 'Oth.ALL.05.Dnmt1.AllCell'
#  'Oth.ALL.05.Dppa3.AllCell' 'Oth.ALL.05.Ezh2.AllCell'
#  'Oth.ALL.05.Smarcad1.AllCell' 'Oth.ALL.05.Phf19.AllCell'
#  'Oth.ALL.05.Rad51.AllCell' 'Oth.ALL.05.Cdyl.AllCell'
#  'Oth.ALL.05.Parp1.AllCell' 'Oth.ALL.05.Irf5.AllCell'
#  'Oth.ALL.05.Irf9.AllCell' 'Oth.ALL.05.Nfe2l1.AllCell'
#  'Oth.ALL.05.Pou2f2.AllCell' 'Oth.ALL.05.Ash1l.AllCell'
#  'Oth.ALL.05.Gps2.AllCell' 'Oth.ALL.05.Thra.AllCell'
#  'Oth.ALL.05.Taf3.AllCell' 'Oth.ALL.05.Fosl1.AllCell'
#  'Oth.ALL.05.Msl1.AllCell' 'Oth.ALL.05.Mafk.AllCell'
#  'Oth.ALL.05.Zfp384.AllCell' 'Oth.ALL.05.Bach1.AllCell'
#  'Oth.ALL.05.Smad2.AllCell' 'Oth.ALL.05.Nono.AllCell'
#  'Oth.ALL.05.Phc1.AllCell' 'Oth.ALL.05.Sox13.AllCell'
#  'Oth.ALL.05.Ints5.AllCell' 'Oth.ALL.05.Hdac6.AllCell'
#  'Oth.ALL.05.Pparg.AllCell' 'Oth.ALL.05.5-hmC.AllCell'
#  'Oth.ALL.05.Pax3.AllCell' 'Oth.ALL.05.Ing1.AllCell'
#  'Oth.ALL.05.Rest.AllCell' 'Oth.ALL.05.Smc3.AllCell'
#  'Oth.ALL.05.Htatsf1.AllCell' 'Oth.ALL.05.Kdm1a.AllCell'
#  'Oth.ALL.05.Hoxa9.AllCell' 'Oth.ALL.05.Kat2a.AllCell'
#  'Oth.ALL.05.Ccar1.AllCell' 'Oth.ALL.05.Brwd1.AllCell'
#  'Oth.ALL.05.Mcrs1.AllCell' 'Oth.ALL.05.Trim33.AllCell'
#  'Oth.ALL.05.Kansl3.AllCell' 'Oth.ALL.05.Stat5a.AllCell'
#  'Oth.ALL.05.Mef2d.AllCell' 'Oth.ALL.05.Npas4.AllCell'
#  'Oth.ALL.05.Spin1.AllCell' 'Oth.ALL.05.Auts2.AllCell'
#  'Oth.ALL.05.Thap11.AllCell' 'Oth.ALL.05.Hoxc8.AllCell'
#  'Oth.ALL.05.Atoh1.AllCell' 'Oth.ALL.05.Nr0b2.AllCell'
#  'Oth.ALL.05.Egr1.AllCell' 'Oth.ALL.05.Sox9.AllCell'
#  'Oth.ALL.05.Ctcfl.AllCell' 'Oth.ALL.05.Lrrfip1.AllCell'
#  'Oth.ALL.05.Mitf.AllCell' 'Oth.ALL.05.Grhl2.AllCell'
#  'Oth.ALL.05.Cpsf3l.AllCell' 'Oth.ALL.05.Foxc2.AllCell'
#  'Oth.ALL.05.Rarg.AllCell' 'Oth.ALL.05.Mafa.AllCell'
#  'Oth.ALL.05.Rnf2.AllCell' 'Oth.ALL.05.Gckr.AllCell'
#  'Oth.ALL.05.Bbx.AllCell' 'Oth.ALL.05.Cbfb.AllCell'
#  'Oth.ALL.05.Lmna.AllCell' 'Oth.ALL.05.Klf2.AllCell'
#  'Oth.ALL.05.Nsl1.AllCell' 'Oth.ALL.05.Erg.AllCell'
#  'Oth.ALL.05.Stat6.AllCell' 'Oth.ALL.05.Mta2.AllCell'
#  'Oth.ALL.05.Duxbl1.AllCell' 'Oth.ALL.05.Maz.AllCell'
#  'Oth.ALL.05.Fam208a.AllCell' 'Oth.ALL.05.Hoxc13.AllCell'
#  'Oth.ALL.05.Hoxa11.AllCell' 'Oth.ALL.05.RAF1.AllCell'
#  'Oth.ALL.05.Hells.AllCell' 'Oth.ALL.05.Med26.AllCell'
#  'Oth.ALL.05.Zscan4c.AllCell' 'Oth.ALL.05.Thrap3.AllCell'
#  'Oth.ALL.05.Rbfox2.AllCell' 'Oth.ALL.05.Elob.AllCell'
#  'Oth.ALL.05.Asxl3.AllCell' 'Oth.ALL.05.Nfyb.AllCell'
#  'Oth.ALL.05.Erf.AllCell' 'Oth.ALL.05.Men1.AllCell'
#  'Oth.ALL.05.Sox17.AllCell' 'Oth.ALL.05.Asxl1.AllCell'
#  'Oth.ALL.05.Xrn2.AllCell' 'Oth.ALL.05.Tal1.AllCell'
#  'Oth.ALL.05.Mphosph8.AllCell' 'Oth.ALL.05.Snai2.AllCell'
#  'Oth.ALL.05.Cbx1.AllCell' 'Oth.ALL.05.Utp6.AllCell'
#  'Oth.ALL.05.Ruvbl2.AllCell' 'Oth.ALL.05.Tead2.AllCell'
#  'Oth.ALL.05.Cbx8.AllCell' 'Oth.ALL.05.Ldb1.AllCell'
#  'Oth.ALL.05.Anp32e.AllCell' 'Oth.ALL.05.Rbbp4.AllCell'
#  'Oth.ALL.05.Pax5.AllCell' 'Oth.ALL.05.Srcap.AllCell'
#  'Oth.ALL.05.Drosha.AllCell' 'Oth.ALL.05.Sp1.AllCell'
#  'Oth.ALL.05.Hnf4a.AllCell' 'Oth.ALL.05.Hoxd13.AllCell'
#  'Oth.ALL.05.Rif1.AllCell' 'Oth.ALL.05.Kdm4c.AllCell'
#  'Oth.ALL.05.Arnt.AllCell' 'Oth.ALL.05.Mkl2.AllCell'
#  'Oth.ALL.05.Ikzf3.AllCell' 'Oth.ALL.05.Brd2.AllCell'
#  'Oth.ALL.05.Kdm6a.AllCell' 'Oth.ALL.05.Kdm4a.AllCell'
#  'Oth.ALL.05.Rbbp5.AllCell' 'Oth.ALL.05.Cdc73.AllCell'
#  'Oth.ALL.05.Ing5.AllCell' 'Oth.ALL.05.Htt.AllCell'
#  'Oth.ALL.05.Ctnnb1.AllCell' 'Oth.ALL.05.Arid4b.AllCell'
#  'Oth.ALL.05.Nr0b1.AllCell' 'Oth.ALL.05.Eloa.AllCell'
#  'Oth.ALL.05.Nfkbia.AllCell' 'Oth.ALL.05.Zfp335.AllCell'
#  'Oth.ALL.05.Ppargc1b.AllCell' 'Oth.ALL.05.Elk1.AllCell'
#  'Oth.ALL.05.Gtf2a2.AllCell' 'Oth.ALL.05.Aicda.AllCell'
#  'Oth.ALL.05.Klf3.AllCell' 'Oth.ALL.05.Pcgf6.AllCell'
#  'Oth.ALL.05.Nkx6-1.AllCell' 'Oth.ALL.05.Fos.AllCell'
#  'Oth.ALL.05.Sall4.AllCell' 'Oth.ALL.05.Banp.AllCell'
#  'Oth.ALL.05.Adnp.AllCell' 'Oth.ALL.05.Hoxb13.AllCell'
#  'Oth.ALL.05.Setd1a.AllCell' 'Oth.ALL.05.Irf1.AllCell'
#  'Oth.ALL.05.Pcna.AllCell' 'Oth.ALL.05.Tbr1.AllCell'
#  'Oth.ALL.05.Zfp143.AllCell' 'Oth.ALL.05.Msl2.AllCell'
#  'Oth.ALL.05.Biotin.AllCell' 'Oth.ALL.05.Srebf2.AllCell'
#  'Oth.ALL.05.Jmjd6.AllCell' 'Oth.ALL.05.Irf8.AllCell'
#  'Oth.ALL.05.Tbp.AllCell' 'Oth.ALL.05.Nfic.AllCell'
#  'Oth.ALL.05.Gfi1b.AllCell' 'Oth.ALL.05.Thap1.AllCell'
#  'Oth.ALL.05.Myt1l.AllCell' 'Oth.ALL.05.Ebf2.AllCell'
#  'Oth.ALL.05.Tead1.AllCell' 'Oth.ALL.05.Zfp42.AllCell'
#  'Oth.ALL.05.Nr1h4.AllCell' 'Oth.ALL.05.Actb.AllCell'
#  'Oth.ALL.05.Tgif1.AllCell' 'Oth.ALL.05.Taf2.AllCell'
#  'Oth.ALL.05.Pou2f1.AllCell' 'Oth.ALL.05.Runx1.AllCell'
#  'Oth.ALL.05.Brd9.AllCell' 'Oth.ALL.05.Nr3c1.AllCell'
#  'Oth.ALL.05.Gli3.AllCell' 'Oth.ALL.05.Mbd2.AllCell'
#  'Oth.ALL.05.Trim28.AllCell' 'Oth.ALL.05.Crotonyl_lysine.AllCell'
#  'Oth.ALL.05.Obox1.AllCell' 'Oth.ALL.05.Foxf1.AllCell'
#  'Oth.ALL.05.Pou2f3.AllCell' 'Oth.ALL.05.Tdg.AllCell'
#  'Oth.ALL.05.Smarca5.AllCell' 'Oth.ALL.05.Srsf2.AllCell'
#  'Oth.ALL.05.Usf1.AllCell' 'Oth.ALL.05.Vdr.AllCell'
#  'Oth.ALL.05.Paxip1.AllCell' 'Oth.ALL.05.Zfp410.AllCell'
#  'Oth.ALL.05.Mesp1.AllCell' 'Oth.ALL.05.Ogdh.AllCell'
#  'Oth.ALL.05.Mbd1.AllCell' 'Oth.ALL.05.Pax6.AllCell'
#  'Oth.ALL.05.L3mbtl2.AllCell' 'Oth.ALL.05.Ncor2.AllCell'
#  'Oth.ALL.05.Zfp541.AllCell' 'Oth.ALL.05.Yy2.AllCell'
#  'Oth.ALL.05.Tsc22d3.AllCell' 'Oth.ALL.05.Myod1.AllCell'
#  'Oth.ALL.05.Mnt.AllCell' 'Oth.ALL.05.Myf5.AllCell'
#  'Oth.ALL.05.Zmynd8.AllCell' 'Oth.ALL.05.Rai1.AllCell'
#  'Oth.ALL.05.Phf7.AllCell' 'Oth.ALL.05.Hic2.AllCell'
#  'Oth.ALL.05.Wapl.AllCell' 'Oth.ALL.05.Tbx21.AllCell'
#  'Oth.ALL.05.Grip1.AllCell' 'Oth.ALL.05.Kdm5b.AllCell'
#  'Oth.ALL.05.Thrb.AllCell' 'Oth.ALL.05.Rfx2.AllCell'
#  'Oth.ALL.05.Jarid2.AllCell' 'Oth.ALL.05.Neurog2.AllCell'
#  'Oth.ALL.05.Rbpjl.AllCell' 'Oth.ALL.05.Kat5.AllCell'
#  'Oth.ALL.05.Zbtb16.AllCell' 'Oth.ALL.05.Chd7.AllCell'
#  'Oth.ALL.05.Peg3.AllCell' 'Oth.ALL.05.Dlx1.AllCell'
#  'Oth.ALL.05.Ebf1.AllCell' 'Oth.ALL.05.Smc5.AllCell'
#  'Oth.ALL.05.Pdx1.AllCell' 'Oth.ALL.05.Rtf1.AllCell'
#  'Oth.ALL.05.Id2.AllCell' 'Oth.ALL.05.Ncoa1.AllCell'
#  'Oth.ALL.05.Lhx5.AllCell' 'Oth.ALL.05.Baz1b.AllCell'
#  'Oth.ALL.05.Rpa1.AllCell' 'Oth.ALL.05.Timeless.AllCell'
#  'Oth.ALL.05.Hdac3.AllCell' 'Oth.ALL.05.Yeats4.AllCell'
#  'Oth.ALL.05.Elk3.AllCell' 'Oth.ALL.05.Kat8.AllCell'
#  'Oth.ALL.05.Art1.AllCell' 'Oth.ALL.05.Aire.AllCell'
#  'Oth.ALL.05.Onecut1.AllCell' 'Oth.ALL.05.Ppard.AllCell'
#  'Oth.ALL.05.Gadd45a.AllCell' 'Oth.ALL.05.Gata2.AllCell'
#  'Oth.ALL.05.Etv2.AllCell' 'Oth.ALL.05.Cry1.AllCell'
#  'Oth.ALL.05.Sin3b.AllCell' 'Oth.ALL.05.5-mC.AllCell'
#  'Oth.ALL.05.Foxj2.AllCell' 'Oth.ALL.05.Tbx19.AllCell'
#  'Oth.ALL.05.Cbx5.AllCell' 'Oth.ALL.05.Atf3.AllCell'
#  'Oth.ALL.05.Olig2.AllCell' 'Oth.ALL.05.Gata1.AllCell'
#  'Oth.ALL.05.E2f4.AllCell' 'Oth.ALL.05.Hoxb4.AllCell'
#  'Oth.ALL.05.Ezh1.AllCell' 'Oth.ALL.05.Msh2.AllCell'
#  'Oth.ALL.05.Dnmt3b.AllCell' 'Oth.ALL.05.Mtf2.AllCell'
#  'Oth.ALL.05.Crx.AllCell' 'Oth.ALL.05.Nup210.AllCell'
#  'Oth.ALL.05.Pou3f1.AllCell' 'Oth.ALL.05.Ints3.AllCell'
#  'Oth.ALL.05.Thoc5.AllCell' 'Oth.ALL.05.Mafb.AllCell'
#  'Oth.ALL.05.Mau2.AllCell' 'Oth.ALL.05.Gata3.AllCell'
#  'Oth.ALL.05.Tfam.AllCell' 'Oth.ALL.05.Tbx20.AllCell'
#  'Oth.ALL.05.Stat4.AllCell' 'Oth.ALL.05.Rad23b.AllCell'
#  'Oth.ALL.05.Cxxc5.AllCell' 'Oth.ALL.05.Sox3.AllCell'
#  'Oth.ALL.05.Nr2f2.AllCell' 'Oth.ALL.05.Kdm2a.AllCell'
#  'Oth.ALL.05.Top2a.AllCell' 'Oth.ALL.05.Hnf4g.AllCell'
#  'Oth.ALL.05.Stag2.AllCell' 'Oth.ALL.05.Ubtf.AllCell'
#  'Oth.ALL.05.Fli1.AllCell' 'Oth.ALL.05.Ssrp1.AllCell'
#  'Oth.ALL.05.Rreb1.AllCell' 'Oth.ALL.05.Macf1.AllCell'
#  'Oth.ALL.05.Socs1.AllCell' 'Oth.ALL.05.Supt16.AllCell'
#  'Oth.ALL.05.T.AllCell' 'Oth.ALL.05.Ep400.AllCell'
#  'Oth.ALL.05.Med12.AllCell' 'Oth.ALL.05.Ctf1.AllCell'
#  'Oth.ALL.05.Esr2.AllCell' 'Oth.ALL.05.Nrf1.AllCell'
#  'Oth.ALL.05.Ctcf.AllCell' 'Oth.ALL.05.Epitope_tags.AllCell'
#  'Oth.ALL.05.Spi1.AllCell']

# %% [markdown]
# Then I ran this code to download the files using os.system to run a linux command that downloads the datasets using wget and then compresses it using gzip
#
# I've turned this command to markdown becuase we don't want to run it again and redownload everything :)
#
#
# ```
# # This is python code to download the files
# path_to_files = '/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/indiv_factors_all_cells.dir/'
#
# import os
# for file in files_for_download:
#     os.system(f'wget -P {path_to_files} https://chip-atlas.dbcls.jp/data/mm10/assembled/{file}.bed && gzip {path_to_files}{file}.bed')
#
# ```
#
# I then ran some linux command line commands and
# 1. used the bedtools program [here](https://bedtools.readthedocs.io/en/latest/content/tools/intersect.html) to merge all the peaks from the different tissues together if they overlapped (this makes the file smaller) using `bedtools merge`.
# 2. I then compressed these using `gzip`
# 3. Then used `bedtools intersect` to overlap all the atac peaks from our study with the peaks of the different transcription factors, and output a file of those peaks that were found to overlap those factors
# 4. Finally then compressed these files using `gzip` - these files are now all in `/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/indiv_factors_all_cells.dir/intersection_with_basson_peaks.dir`
# 5. Then i tidyied up the filenames using `mv`
#
# Here is the linux code:
#
# ```
# cd /project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/indiv_factors_all_cells.dir
#
# for file in *.bed.gz; do bedtools merge $file > $file.merged.bed; done
#
# gzip *.merged.bed
#
# for f in *merged.bed.gz; do bedtools intersect -a ../../../all_basson_cerebellarWTminR123_peaks.bed -b $f  -wa > intersection_with_basson_peaks.dir/basson_cere_WTmin123_in_$f.bed; done
#
# gzip *bed
#
# for f in ./*; do mv "$f" "${f%.bed.gz.merged.bed.gz.bed.gz}.bed.gz" ; done
# ```

# %% [markdown]
# You can see all the origional downloaded files and thier merged counterparks here:

# %%
! ls /project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/indiv_factors_all_cells.dir
# Out:
# intersection_with_basson_peaks.dir
# Oth.ALL.05.0610010K14Rik.AllCell.bed.gz
# Oth.ALL.05.0610010K14Rik.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.5-hmC.AllCell.bed.gz
# Oth.ALL.05.5-hmC.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.5-mC.AllCell.bed.gz
# Oth.ALL.05.5-mC.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.8-Hydroxydeoxyguanosine.AllCell.bed.gz
# Oth.ALL.05.8-Hydroxydeoxyguanosine.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Acaa2.AllCell.bed.gz
# Oth.ALL.05.Acaa2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Acss2.AllCell.bed.gz
# Oth.ALL.05.Acss2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Actb.AllCell.bed.gz
# Oth.ALL.05.Actb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Adnp.AllCell.bed.gz
# Oth.ALL.05.Adnp.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.ADP-ribose.AllCell.bed.gz
# Oth.ALL.05.ADP-ribose.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Aebp2.AllCell.bed.gz
# Oth.ALL.05.Aebp2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Aff3.AllCell.bed.gz
# Oth.ALL.05.Aff3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Aff4.AllCell.bed.gz
# Oth.ALL.05.Aff4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ago2.AllCell.bed.gz
# Oth.ALL.05.Ago2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ahcy.AllCell.bed.gz
# Oth.ALL.05.Ahcy.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ahr.AllCell.bed.gz
# Oth.ALL.05.Ahr.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Aicda.AllCell.bed.gz
# Oth.ALL.05.Aicda.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Aire.AllCell.bed.gz
# Oth.ALL.05.Aire.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Alkbh5.AllCell.bed.gz
# Oth.ALL.05.Alkbh5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.AML1-ETO.AllCell.bed.gz
# Oth.ALL.05.AML1-ETO.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Anp32e.AllCell.bed.gz
# Oth.ALL.05.Anp32e.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ar.AllCell.bed.gz
# Oth.ALL.05.Ar.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Arid1a.AllCell.bed.gz
# Oth.ALL.05.Arid1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Arid1b.AllCell.bed.gz
# Oth.ALL.05.Arid1b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Arid2.AllCell.bed.gz
# Oth.ALL.05.Arid2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Arid3a.AllCell.bed.gz
# Oth.ALL.05.Arid3a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Arid4b.AllCell.bed.gz
# Oth.ALL.05.Arid4b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Arid5a.AllCell.bed.gz
# Oth.ALL.05.Arid5a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Arnt.AllCell.bed.gz
# Oth.ALL.05.Arnt.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Arntl.AllCell.bed.gz
# Oth.ALL.05.Arntl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Art1.AllCell.bed.gz
# Oth.ALL.05.Art1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ascl1.AllCell.bed.gz
# Oth.ALL.05.Ascl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ascl2.AllCell.bed.gz
# Oth.ALL.05.Ascl2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ash1l.AllCell.bed.gz
# Oth.ALL.05.Ash1l.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ash2l.AllCell.bed.gz
# Oth.ALL.05.Ash2l.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Asxl1.AllCell.bed.gz
# Oth.ALL.05.Asxl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Asxl3.AllCell.bed.gz
# Oth.ALL.05.Asxl3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Atf2.AllCell.bed.gz
# Oth.ALL.05.Atf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Atf3.AllCell.bed.gz
# Oth.ALL.05.Atf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Atf4.AllCell.bed.gz
# Oth.ALL.05.Atf4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Atf7.AllCell.bed.gz
# Oth.ALL.05.Atf7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Atf7ip.AllCell.bed.gz
# Oth.ALL.05.Atf7ip.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Atm.AllCell.bed.gz
# Oth.ALL.05.Atm.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Atoh1.AllCell.bed.gz
# Oth.ALL.05.Atoh1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Atrx.AllCell.bed.gz
# Oth.ALL.05.Atrx.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Auts2.AllCell.bed.gz
# Oth.ALL.05.Auts2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bach1.AllCell.bed.gz
# Oth.ALL.05.Bach1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bach2.AllCell.bed.gz
# Oth.ALL.05.Bach2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Banp.AllCell.bed.gz
# Oth.ALL.05.Banp.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bap1.AllCell.bed.gz
# Oth.ALL.05.Bap1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Batf3.AllCell.bed.gz
# Oth.ALL.05.Batf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Batf.AllCell.bed.gz
# Oth.ALL.05.Batf.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Baz1a.AllCell.bed.gz
# Oth.ALL.05.Baz1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Baz1b.AllCell.bed.gz
# Oth.ALL.05.Baz1b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Baz2a.AllCell.bed.gz
# Oth.ALL.05.Baz2a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bbx.AllCell.bed.gz
# Oth.ALL.05.Bbx.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bcl11a.AllCell.bed.gz
# Oth.ALL.05.Bcl11a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bcl11b.AllCell.bed.gz
# Oth.ALL.05.Bcl11b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bcl6.AllCell.bed.gz
# Oth.ALL.05.Bcl6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bcor.AllCell.bed.gz
# Oth.ALL.05.Bcor.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bhlhe40.AllCell.bed.gz
# Oth.ALL.05.Bhlhe40.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bhlhe41.AllCell.bed.gz
# Oth.ALL.05.Bhlhe41.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Biotin.AllCell.bed.gz
# Oth.ALL.05.Biotin.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bmi1.AllCell.bed.gz
# Oth.ALL.05.Bmi1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Bnc1.AllCell.bed.gz
# Oth.ALL.05.Bnc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brca1.AllCell.bed.gz
# Oth.ALL.05.Brca1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brca2.AllCell.bed.gz
# Oth.ALL.05.Brca2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brd2.AllCell.bed.gz
# Oth.ALL.05.Brd2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brd3.AllCell.bed.gz
# Oth.ALL.05.Brd3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brd4.AllCell.bed.gz
# Oth.ALL.05.Brd4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brd7.AllCell.bed.gz
# Oth.ALL.05.Brd7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brd9.AllCell.bed.gz
# Oth.ALL.05.Brd9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brdt.AllCell.bed.gz
# Oth.ALL.05.Brdt.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.BrdU.AllCell.bed.gz
# Oth.ALL.05.BrdU.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Brwd1.AllCell.bed.gz
# Oth.ALL.05.Brwd1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Btaf1.AllCell.bed.gz
# Oth.ALL.05.Btaf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Butyryllysine.AllCell.bed.gz
# Oth.ALL.05.Butyryllysine.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Carm1.AllCell.bed.gz
# Oth.ALL.05.Carm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cas9.AllCell.bed.gz
# Oth.ALL.05.Cas9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbfa2t2.AllCell.bed.gz
# Oth.ALL.05.Cbfa2t2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbfa2t3.AllCell.bed.gz
# Oth.ALL.05.Cbfa2t3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbfb.AllCell.bed.gz
# Oth.ALL.05.Cbfb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbx1.AllCell.bed.gz
# Oth.ALL.05.Cbx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbx2.AllCell.bed.gz
# Oth.ALL.05.Cbx2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbx3.AllCell.bed.gz
# Oth.ALL.05.Cbx3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbx4.AllCell.bed.gz
# Oth.ALL.05.Cbx4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbx5.AllCell.bed.gz
# Oth.ALL.05.Cbx5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbx7.AllCell.bed.gz
# Oth.ALL.05.Cbx7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cbx8.AllCell.bed.gz
# Oth.ALL.05.Cbx8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ccar1.AllCell.bed.gz
# Oth.ALL.05.Ccar1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ccnk.AllCell.bed.gz
# Oth.ALL.05.Ccnk.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cd38.AllCell.bed.gz
# Oth.ALL.05.Cd38.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cdc73.AllCell.bed.gz
# Oth.ALL.05.Cdc73.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cdk7.AllCell.bed.gz
# Oth.ALL.05.Cdk7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cdk8.AllCell.bed.gz
# Oth.ALL.05.Cdk8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cdk9.AllCell.bed.gz
# Oth.ALL.05.Cdk9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cdx2.AllCell.bed.gz
# Oth.ALL.05.Cdx2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cdyl.AllCell.bed.gz
# Oth.ALL.05.Cdyl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cebpa.AllCell.bed.gz
# Oth.ALL.05.CEBPA.AllCell.bed.gz
# Oth.ALL.05.Cebpa.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.CEBPA.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cebpb.AllCell.bed.gz
# Oth.ALL.05.Cebpb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cebpd.AllCell.bed.gz
# Oth.ALL.05.Cebpd.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cebpe.AllCell.bed.gz
# Oth.ALL.05.Cebpe.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cebpg.AllCell.bed.gz
# Oth.ALL.05.Cebpg.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Chaf1b.AllCell.bed.gz
# Oth.ALL.05.Chaf1b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Chd1.AllCell.bed.gz
# Oth.ALL.05.Chd1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Chd2.AllCell.bed.gz
# Oth.ALL.05.Chd2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Chd4.AllCell.bed.gz
# Oth.ALL.05.Chd4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Chd7.AllCell.bed.gz
# Oth.ALL.05.Chd7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Chd8.AllCell.bed.gz
# Oth.ALL.05.Chd8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Chuk.AllCell.bed.gz
# Oth.ALL.05.Chuk.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cirh1a.AllCell.bed.gz
# Oth.ALL.05.Cirh1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Clock.AllCell.bed.gz
# Oth.ALL.05.Clock.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cpsf3l.AllCell.bed.gz
# Oth.ALL.05.Cpsf3l.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Creb1.AllCell.bed.gz
# Oth.ALL.05.Creb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Creb3l2.AllCell.bed.gz
# Oth.ALL.05.Creb3l2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Crebbp.AllCell.bed.gz
# Oth.ALL.05.Crebbp.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Crotonyl_lysine.AllCell.bed.gz
# Oth.ALL.05.Crotonyl_lysine.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Crtc2.AllCell.bed.gz
# Oth.ALL.05.Crtc2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Crtc3.AllCell.bed.gz
# Oth.ALL.05.Crtc3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Crx.AllCell.bed.gz
# Oth.ALL.05.Crx.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cry1.AllCell.bed.gz
# Oth.ALL.05.Cry1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ctbp2.AllCell.bed.gz
# Oth.ALL.05.Ctbp2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ctcf.AllCell.bed.gz
# Oth.ALL.05.Ctcf.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ctcfl.AllCell.bed.gz
# Oth.ALL.05.Ctcfl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ctf1.AllCell.bed.gz
# Oth.ALL.05.Ctf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ctnnb1.AllCell.bed.gz
# Oth.ALL.05.Ctnnb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ctr9.AllCell.bed.gz
# Oth.ALL.05.Ctr9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cux2.AllCell.bed.gz
# Oth.ALL.05.Cux2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cxxc1.AllCell.bed.gz
# Oth.ALL.05.Cxxc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Cxxc5.AllCell.bed.gz
# Oth.ALL.05.Cxxc5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Daxx.AllCell.bed.gz
# Oth.ALL.05.Daxx.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dbp.AllCell.bed.gz
# Oth.ALL.05.Dbp.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ddit3.AllCell.bed.gz
# Oth.ALL.05.Ddit3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ddx18.AllCell.bed.gz
# Oth.ALL.05.Ddx18.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ddx1.AllCell.bed.gz
# Oth.ALL.05.Ddx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ddx21.AllCell.bed.gz
# Oth.ALL.05.Ddx21.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ddx5.AllCell.bed.gz
# Oth.ALL.05.Ddx5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dendra2.AllCell.bed.gz
# Oth.ALL.05.Dendra2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dgcr8.AllCell.bed.gz
# Oth.ALL.05.Dgcr8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dhx9.AllCell.bed.gz
# Oth.ALL.05.Dhx9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dicer1.AllCell.bed.gz
# Oth.ALL.05.Dicer1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dlx1.AllCell.bed.gz
# Oth.ALL.05.Dlx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dlx3.AllCell.bed.gz
# Oth.ALL.05.Dlx3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dmap1.AllCell.bed.gz
# Oth.ALL.05.Dmap1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dmc1.AllCell.bed.gz
# Oth.ALL.05.Dmc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dmrt1.AllCell.bed.gz
# Oth.ALL.05.Dmrt1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dmrtb1.AllCell.bed.gz
# Oth.ALL.05.Dmrtb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dnajc2.AllCell.bed.gz
# Oth.ALL.05.Dnajc2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.DNA-RNA_hybrid.AllCell.bed.gz
# Oth.ALL.05.DNA-RNA_hybrid.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dnmt1.AllCell.bed.gz
# Oth.ALL.05.Dnmt1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dnmt3a.AllCell.bed.gz
# Oth.ALL.05.Dnmt3a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dnmt3b.AllCell.bed.gz
# Oth.ALL.05.Dnmt3b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dnmt3l.AllCell.bed.gz
# Oth.ALL.05.Dnmt3l.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dnttip1.AllCell.bed.gz
# Oth.ALL.05.Dnttip1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dpf2.AllCell.bed.gz
# Oth.ALL.05.Dpf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dpf3.AllCell.bed.gz
# Oth.ALL.05.Dpf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dppa2.AllCell.bed.gz
# Oth.ALL.05.Dppa2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dppa3.AllCell.bed.gz
# Oth.ALL.05.Dppa3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dppa4.AllCell.bed.gz
# Oth.ALL.05.Dppa4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dpy30.AllCell.bed.gz
# Oth.ALL.05.Dpy30.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Dr1.AllCell.bed.gz
# Oth.ALL.05.Dr1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Drosha.AllCell.bed.gz
# Oth.ALL.05.Drosha.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Duxbl1.AllCell.bed.gz
# Oth.ALL.05.Duxbl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.E2f1.AllCell.bed.gz
# Oth.ALL.05.E2f1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.E2f3.AllCell.bed.gz
# Oth.ALL.05.E2f3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.E2f4.AllCell.bed.gz
# Oth.ALL.05.E2f4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.E2f6.AllCell.bed.gz
# Oth.ALL.05.E2f6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.E4f1.AllCell.bed.gz
# Oth.ALL.05.E4f1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ebf1.AllCell.bed.gz
# Oth.ALL.05.Ebf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ebf2.AllCell.bed.gz
# Oth.ALL.05.Ebf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ebf4.AllCell.bed.gz
# Oth.ALL.05.Ebf4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Eed.AllCell.bed.gz
# Oth.ALL.05.Eed.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Egr1.AllCell.bed.gz
# Oth.ALL.05.Egr1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Egr2.AllCell.bed.gz
# Oth.ALL.05.Egr2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ehf.AllCell.bed.gz
# Oth.ALL.05.Ehf.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ehmt2.AllCell.bed.gz
# Oth.ALL.05.Ehmt2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Elf1.AllCell.bed.gz
# Oth.ALL.05.Elf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Elf4.AllCell.bed.gz
# Oth.ALL.05.Elf4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Elf5.AllCell.bed.gz
# Oth.ALL.05.Elf5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Elk1.AllCell.bed.gz
# Oth.ALL.05.Elk1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Elk3.AllCell.bed.gz
# Oth.ALL.05.Elk3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Elk4.AllCell.bed.gz
# Oth.ALL.05.Elk4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ell2.AllCell.bed.gz
# Oth.ALL.05.Ell2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ell3.AllCell.bed.gz
# Oth.ALL.05.Ell3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ell.AllCell.bed.gz
# Oth.ALL.05.Ell.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Eloa.AllCell.bed.gz
# Oth.ALL.05.Eloa.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Elob.AllCell.bed.gz
# Oth.ALL.05.Elob.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Emx2.AllCell.bed.gz
# Oth.ALL.05.Emx2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Eomes.AllCell.bed.gz
# Oth.ALL.05.Eomes.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ep300.AllCell.bed.gz
# Oth.ALL.05.Ep300.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ep400.AllCell.bed.gz
# Oth.ALL.05.Ep400.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Epitope_tags.AllCell.bed.gz
# Oth.ALL.05.Epitope_tags.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Epop.AllCell.bed.gz
# Oth.ALL.05.Epop.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ercc3.AllCell.bed.gz
# Oth.ALL.05.Ercc3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Erf.AllCell.bed.gz
# Oth.ALL.05.Erf.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Erg.AllCell.bed.gz
# Oth.ALL.05.Erg.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Esr1.AllCell.bed.gz
# Oth.ALL.05.Esr1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Esr2.AllCell.bed.gz
# Oth.ALL.05.Esr2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Esrra.AllCell.bed.gz
# Oth.ALL.05.Esrra.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Esrrb.AllCell.bed.gz
# Oth.ALL.05.Esrrb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Esrrg.AllCell.bed.gz
# Oth.ALL.05.Esrrg.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ets1.AllCell.bed.gz
# Oth.ALL.05.Ets1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ets2.AllCell.bed.gz
# Oth.ALL.05.Ets2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Etv2.AllCell.bed.gz
# Oth.ALL.05.Etv2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Etv5.AllCell.bed.gz
# Oth.ALL.05.Etv5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Etv6.AllCell.bed.gz
# Oth.ALL.05.Etv6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ezh1.AllCell.bed.gz
# Oth.ALL.05.Ezh1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ezh2.AllCell.bed.gz
# Oth.ALL.05.Ezh2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fam208a.AllCell.bed.gz
# Oth.ALL.05.Fam208a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fam60a.AllCell.bed.gz
# Oth.ALL.05.Fam60a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fbxo21.AllCell.bed.gz
# Oth.ALL.05.Fbxo21.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fev.AllCell.bed.gz
# Oth.ALL.05.Fev.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fgfr1.AllCell.bed.gz
# Oth.ALL.05.Fgfr1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fli1.AllCell.bed.gz
# Oth.ALL.05.Fli1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fo.AllCell.bed.gz
# Oth.ALL.05.Fo.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fos.AllCell.bed.gz
# Oth.ALL.05.Fos.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fosb.AllCell.bed.gz
# Oth.ALL.05.Fosb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fosl1.AllCell.bed.gz
# Oth.ALL.05.Fosl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Fosl2.AllCell.bed.gz
# Oth.ALL.05.Fosl2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxa1.AllCell.bed.gz
# Oth.ALL.05.Foxa1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxa2.AllCell.bed.gz
# Oth.ALL.05.Foxa2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxa3.AllCell.bed.gz
# Oth.ALL.05.Foxa3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxc1.AllCell.bed.gz
# Oth.ALL.05.Foxc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxc2.AllCell.bed.gz
# Oth.ALL.05.Foxc2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxf1.AllCell.bed.gz
# Oth.ALL.05.Foxf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxg1.AllCell.bed.gz
# Oth.ALL.05.Foxg1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxh1.AllCell.bed.gz
# Oth.ALL.05.Foxh1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxj2.AllCell.bed.gz
# Oth.ALL.05.Foxj2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxk1.AllCell.bed.gz
# Oth.ALL.05.Foxk1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxk2.AllCell.bed.gz
# Oth.ALL.05.Foxk2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxl2.AllCell.bed.gz
# Oth.ALL.05.Foxl2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxo1.AllCell.bed.gz
# Oth.ALL.05.Foxo1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxo3.AllCell.bed.gz
# Oth.ALL.05.Foxo3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxp1.AllCell.bed.gz
# Oth.ALL.05.Foxp1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxp2.AllCell.bed.gz
# Oth.ALL.05.Foxp2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Foxp3.AllCell.bed.gz
# Oth.ALL.05.Foxp3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gabpa.AllCell.bed.gz
# Oth.ALL.05.Gabpa.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gad1.AllCell.bed.gz
# Oth.ALL.05.Gad1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gadd45a.AllCell.bed.gz
# Oth.ALL.05.Gadd45a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gata1.AllCell.bed.gz
# Oth.ALL.05.Gata1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gata2.AllCell.bed.gz
# Oth.ALL.05.Gata2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gata3.AllCell.bed.gz
# Oth.ALL.05.Gata3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gata4.AllCell.bed.gz
# Oth.ALL.05.Gata4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gata6.AllCell.bed.gz
# Oth.ALL.05.Gata6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gckr.AllCell.bed.gz
# Oth.ALL.05.Gckr.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gcm1.AllCell.bed.gz
# Oth.ALL.05.Gcm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gfi1.AllCell.bed.gz
# Oth.ALL.05.Gfi1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gfi1b.AllCell.bed.gz
# Oth.ALL.05.Gfi1b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.GFP.AllCell.bed.gz
# Oth.ALL.05.GFP.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gli1.AllCell.bed.gz
# Oth.ALL.05.Gli1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gli2.AllCell.bed.gz
# Oth.ALL.05.Gli2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gli3.AllCell.bed.gz
# Oth.ALL.05.Gli3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Glis3.AllCell.bed.gz
# Oth.ALL.05.Glis3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Glyr1.AllCell.bed.gz
# Oth.ALL.05.Glyr1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gmnn.AllCell.bed.gz
# Oth.ALL.05.Gmnn.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gps2.AllCell.bed.gz
# Oth.ALL.05.Gps2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Grhl2.AllCell.bed.gz
# Oth.ALL.05.Grhl2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Grhl3.AllCell.bed.gz
# Oth.ALL.05.Grhl3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Grip1.AllCell.bed.gz
# Oth.ALL.05.Grip1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gsk3b.AllCell.bed.gz
# Oth.ALL.05.Gsk3b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gtf2a2.AllCell.bed.gz
# Oth.ALL.05.Gtf2a2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gtf2b.AllCell.bed.gz
# Oth.ALL.05.Gtf2b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gtf2e2.AllCell.bed.gz
# Oth.ALL.05.Gtf2e2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gtf2f1.AllCell.bed.gz
# Oth.ALL.05.Gtf2f1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Gtf3c1.AllCell.bed.gz
# Oth.ALL.05.Gtf3c1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.H1foo.AllCell.bed.gz
# Oth.ALL.05.H1foo.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hand1.AllCell.bed.gz
# Oth.ALL.05.Hand1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hand2.AllCell.bed.gz
# Oth.ALL.05.Hand2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.HBx.AllCell.bed.gz
# Oth.ALL.05.HBx.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hcfc1.AllCell.bed.gz
# Oth.ALL.05.Hcfc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdac1.AllCell.bed.gz
# Oth.ALL.05.Hdac1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdac2.AllCell.bed.gz
# Oth.ALL.05.Hdac2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdac3.AllCell.bed.gz
# Oth.ALL.05.Hdac3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdac4.AllCell.bed.gz
# Oth.ALL.05.Hdac4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdac5.AllCell.bed.gz
# Oth.ALL.05.Hdac5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdac6.AllCell.bed.gz
# Oth.ALL.05.Hdac6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdac7.AllCell.bed.gz
# Oth.ALL.05.Hdac7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdgf2.AllCell.bed.gz
# Oth.ALL.05.Hdgf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hdgfrp2.AllCell.bed.gz
# Oth.ALL.05.Hdgfrp2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hells.AllCell.bed.gz
# Oth.ALL.05.Hells.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hes1.AllCell.bed.gz
# Oth.ALL.05.Hes1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hexim1.AllCell.bed.gz
# Oth.ALL.05.Hexim1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Heyl.AllCell.bed.gz
# Oth.ALL.05.Heyl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hic2.AllCell.bed.gz
# Oth.ALL.05.Hic2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hif1a.AllCell.bed.gz
# Oth.ALL.05.Hif1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hira.AllCell.bed.gz
# Oth.ALL.05.Hira.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hmga2.AllCell.bed.gz
# Oth.ALL.05.Hmga2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hmgn2.AllCell.bed.gz
# Oth.ALL.05.Hmgn2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hnf1a.AllCell.bed.gz
# Oth.ALL.05.Hnf1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hnf1b.AllCell.bed.gz
# Oth.ALL.05.Hnf1b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hnf4a.AllCell.bed.gz
# Oth.ALL.05.Hnf4a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hnf4g.AllCell.bed.gz
# Oth.ALL.05.Hnf4g.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hnrnpk.AllCell.bed.gz
# Oth.ALL.05.Hnrnpk.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hnrnpl.AllCell.bed.gz
# Oth.ALL.05.Hnrnpl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hnrnpu.AllCell.bed.gz
# Oth.ALL.05.Hnrnpu.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hnrnpul1.AllCell.bed.gz
# Oth.ALL.05.Hnrnpul1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hopx.AllCell.bed.gz
# Oth.ALL.05.Hopx.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxa11.AllCell.bed.gz
# Oth.ALL.05.Hoxa11.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxa13.AllCell.bed.gz
# Oth.ALL.05.Hoxa13.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxa9.AllCell.bed.gz
# Oth.ALL.05.Hoxa9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxb13.AllCell.bed.gz
# Oth.ALL.05.Hoxb13.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxb1.AllCell.bed.gz
# Oth.ALL.05.Hoxb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxb4.AllCell.bed.gz
# Oth.ALL.05.Hoxb4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxc10.AllCell.bed.gz
# Oth.ALL.05.Hoxc10.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxc13.AllCell.bed.gz
# Oth.ALL.05.Hoxc13.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxc6.AllCell.bed.gz
# Oth.ALL.05.Hoxc6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxc8.AllCell.bed.gz
# Oth.ALL.05.Hoxc8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxc9.AllCell.bed.gz
# Oth.ALL.05.Hoxc9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxd13.AllCell.bed.gz
# Oth.ALL.05.Hoxd13.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hoxd9.AllCell.bed.gz
# Oth.ALL.05.Hoxd9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hsf1.AllCell.bed.gz
# Oth.ALL.05.Hsf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Hsf2.AllCell.bed.gz
# Oth.ALL.05.Hsf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Htatsf1.AllCell.bed.gz
# Oth.ALL.05.Htatsf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Htt.AllCell.bed.gz
# Oth.ALL.05.Htt.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Id2.AllCell.bed.gz
# Oth.ALL.05.Id2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ikzf1.AllCell.bed.gz
# Oth.ALL.05.Ikzf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ikzf2.AllCell.bed.gz
# Oth.ALL.05.Ikzf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ikzf3.AllCell.bed.gz
# Oth.ALL.05.Ikzf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ing1.AllCell.bed.gz
# Oth.ALL.05.Ing1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ing5.AllCell.bed.gz
# Oth.ALL.05.Ing5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ino80.AllCell.bed.gz
# Oth.ALL.05.Ino80.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Insm1.AllCell.bed.gz
# Oth.ALL.05.Insm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ints3.AllCell.bed.gz
# Oth.ALL.05.Ints3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ints5.AllCell.bed.gz
# Oth.ALL.05.Ints5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf1.AllCell.bed.gz
# Oth.ALL.05.Irf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf2.AllCell.bed.gz
# Oth.ALL.05.Irf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf2bp2.AllCell.bed.gz
# Oth.ALL.05.Irf2bp2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf3.AllCell.bed.gz
# Oth.ALL.05.Irf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf4.AllCell.bed.gz
# Oth.ALL.05.Irf4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf5.AllCell.bed.gz
# Oth.ALL.05.Irf5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf7.AllCell.bed.gz
# Oth.ALL.05.Irf7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf8.AllCell.bed.gz
# Oth.ALL.05.Irf8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Irf9.AllCell.bed.gz
# Oth.ALL.05.Irf9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Isl1.AllCell.bed.gz
# Oth.ALL.05.Isl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Jarid2.AllCell.bed.gz
# Oth.ALL.05.Jarid2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Jmjd1c.AllCell.bed.gz
# Oth.ALL.05.Jmjd1c.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Jmjd6.AllCell.bed.gz
# Oth.ALL.05.Jmjd6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Jun.AllCell.bed.gz
# Oth.ALL.05.Jun.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Junb.AllCell.bed.gz
# Oth.ALL.05.Junb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Jund.AllCell.bed.gz
# Oth.ALL.05.Jund.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kansl3.AllCell.bed.gz
# Oth.ALL.05.Kansl3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kat2a.AllCell.bed.gz
# Oth.ALL.05.Kat2a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kat2b.AllCell.bed.gz
# Oth.ALL.05.Kat2b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kat5.AllCell.bed.gz
# Oth.ALL.05.Kat5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kat7.AllCell.bed.gz
# Oth.ALL.05.Kat7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kat8.AllCell.bed.gz
# Oth.ALL.05.Kat8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm1a.AllCell.bed.gz
# Oth.ALL.05.Kdm1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm2a.AllCell.bed.gz
# Oth.ALL.05.Kdm2a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm2b.AllCell.bed.gz
# Oth.ALL.05.Kdm2b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm3a.AllCell.bed.gz
# Oth.ALL.05.Kdm3a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm3b.AllCell.bed.gz
# Oth.ALL.05.Kdm3b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm4a.AllCell.bed.gz
# Oth.ALL.05.Kdm4a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm4b.AllCell.bed.gz
# Oth.ALL.05.Kdm4b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm4c.AllCell.bed.gz
# Oth.ALL.05.Kdm4c.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm4d.AllCell.bed.gz
# Oth.ALL.05.Kdm4d.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm5a.AllCell.bed.gz
# Oth.ALL.05.Kdm5a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm5b.AllCell.bed.gz
# Oth.ALL.05.Kdm5b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm5c.AllCell.bed.gz
# Oth.ALL.05.Kdm5c.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm6a.AllCell.bed.gz
# Oth.ALL.05.Kdm6a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kdm6b.AllCell.bed.gz
# Oth.ALL.05.Kdm6b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Klf15.AllCell.bed.gz
# Oth.ALL.05.Klf15.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Klf2.AllCell.bed.gz
# Oth.ALL.05.Klf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Klf3.AllCell.bed.gz
# Oth.ALL.05.Klf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Klf4.AllCell.bed.gz
# Oth.ALL.05.Klf4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Klf5.AllCell.bed.gz
# Oth.ALL.05.Klf5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Klf6.AllCell.bed.gz
# Oth.ALL.05.Klf6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Klf9.AllCell.bed.gz
# Oth.ALL.05.Klf9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kmt2a.AllCell.bed.gz
# Oth.ALL.05.Kmt2a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kmt2b.AllCell.bed.gz
# Oth.ALL.05.Kmt2b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kmt2c.AllCell.bed.gz
# Oth.ALL.05.Kmt2c.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Kmt2d.AllCell.bed.gz
# Oth.ALL.05.Kmt2d.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.L3mbtl2.AllCell.bed.gz
# Oth.ALL.05.L3mbtl2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.L3mbtl3.AllCell.bed.gz
# Oth.ALL.05.L3mbtl3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ldb1.AllCell.bed.gz
# Oth.ALL.05.Ldb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lef1.AllCell.bed.gz
# Oth.ALL.05.Lef1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Leo1.AllCell.bed.gz
# Oth.ALL.05.Leo1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lhx2.AllCell.bed.gz
# Oth.ALL.05.Lhx2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lhx3.AllCell.bed.gz
# Oth.ALL.05.Lhx3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lhx5.AllCell.bed.gz
# Oth.ALL.05.Lhx5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lhx6.AllCell.bed.gz
# Oth.ALL.05.Lhx6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lin9.AllCell.bed.gz
# Oth.ALL.05.Lin9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lmna.AllCell.bed.gz
# Oth.ALL.05.Lmna.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lmnb1.AllCell.bed.gz
# Oth.ALL.05.Lmnb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lmo2.AllCell.bed.gz
# Oth.ALL.05.Lmo2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lmx1b.AllCell.bed.gz
# Oth.ALL.05.Lmx1b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lrrfip1.AllCell.bed.gz
# Oth.ALL.05.Lrrfip1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lyl1.AllCell.bed.gz
# Oth.ALL.05.Lyl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Lysin_homocysteine.AllCell.bed.gz
# Oth.ALL.05.Lysin_homocysteine.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Macf1.AllCell.bed.gz
# Oth.ALL.05.Macf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mafa.AllCell.bed.gz
# Oth.ALL.05.Mafa.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Maf.AllCell.bed.gz
# Oth.ALL.05.Maf.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mafb.AllCell.bed.gz
# Oth.ALL.05.Mafb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Maff.AllCell.bed.gz
# Oth.ALL.05.Maff.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mafg.AllCell.bed.gz
# Oth.ALL.05.Mafg.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mafk.AllCell.bed.gz
# Oth.ALL.05.Mafk.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mapk8.AllCell.bed.gz
# Oth.ALL.05.Mapk8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Matr3.AllCell.bed.gz
# Oth.ALL.05.Matr3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mau2.AllCell.bed.gz
# Oth.ALL.05.Mau2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Max.AllCell.bed.gz
# Oth.ALL.05.Max.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Maz.AllCell.bed.gz
# Oth.ALL.05.Maz.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mbd1.AllCell.bed.gz
# Oth.ALL.05.Mbd1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mbd2.AllCell.bed.gz
# Oth.ALL.05.Mbd2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mbd3.AllCell.bed.gz
# Oth.ALL.05.Mbd3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mcrs1.AllCell.bed.gz
# Oth.ALL.05.Mcrs1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mecp2.AllCell.bed.gz
# Oth.ALL.05.Mecp2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Med12.AllCell.bed.gz
# Oth.ALL.05.Med12.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Med14.AllCell.bed.gz
# Oth.ALL.05.Med14.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Med1.AllCell.bed.gz
# Oth.ALL.05.Med1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Med23.AllCell.bed.gz
# Oth.ALL.05.Med23.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Med24.AllCell.bed.gz
# Oth.ALL.05.Med24.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Med26.AllCell.bed.gz
# Oth.ALL.05.Med26.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Med4.AllCell.bed.gz
# Oth.ALL.05.Med4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mef2a.AllCell.bed.gz
# Oth.ALL.05.Mef2a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mef2c.AllCell.bed.gz
# Oth.ALL.05.Mef2c.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mef2d.AllCell.bed.gz
# Oth.ALL.05.Mef2d.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Meiosin.AllCell.bed.gz
# Oth.ALL.05.Meiosin.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Meis1.AllCell.bed.gz
# Oth.ALL.05.Meis1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Men1.AllCell.bed.gz
# Oth.ALL.05.Men1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mesp1.AllCell.bed.gz
# Oth.ALL.05.Mesp1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mettl14.AllCell.bed.gz
# Oth.ALL.05.Mettl14.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mettl3.AllCell.bed.gz
# Oth.ALL.05.Mettl3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mitf.AllCell.bed.gz
# Oth.ALL.05.Mitf.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mkl1.AllCell.bed.gz
# Oth.ALL.05.Mkl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mkl2.AllCell.bed.gz
# Oth.ALL.05.Mkl2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mllt10.AllCell.bed.gz
# Oth.ALL.05.Mllt10.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mllt3.AllCell.bed.gz
# Oth.ALL.05.Mllt3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mlxipl.AllCell.bed.gz
# Oth.ALL.05.Mlxipl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mnt.AllCell.bed.gz
# Oth.ALL.05.Mnt.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mnx1.AllCell.bed.gz
# Oth.ALL.05.Mnx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Morc3.AllCell.bed.gz
# Oth.ALL.05.Morc3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mphosph8.AllCell.bed.gz
# Oth.ALL.05.Mphosph8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mpnd.AllCell.bed.gz
# Oth.ALL.05.Mpnd.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mre11a.AllCell.bed.gz
# Oth.ALL.05.Mre11a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Msh2.AllCell.bed.gz
# Oth.ALL.05.Msh2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Msh6.AllCell.bed.gz
# Oth.ALL.05.Msh6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Msl1.AllCell.bed.gz
# Oth.ALL.05.Msl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Msl2.AllCell.bed.gz
# Oth.ALL.05.Msl2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mta1.AllCell.bed.gz
# Oth.ALL.05.Mta1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mta2.AllCell.bed.gz
# Oth.ALL.05.Mta2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mtf2.AllCell.bed.gz
# Oth.ALL.05.Mtf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mtor.AllCell.bed.gz
# Oth.ALL.05.Mtor.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mxi1.AllCell.bed.gz
# Oth.ALL.05.Mxi1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Myb.AllCell.bed.gz
# Oth.ALL.05.Myb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mybl1.AllCell.bed.gz
# Oth.ALL.05.Mybl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Myc.AllCell.bed.gz
# Oth.ALL.05.Myc.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mycn.AllCell.bed.gz
# Oth.ALL.05.Mycn.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Myf5.AllCell.bed.gz
# Oth.ALL.05.Myf5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Myo1c.AllCell.bed.gz
# Oth.ALL.05.Myo1c.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Myod1.AllCell.bed.gz
# Oth.ALL.05.Myod1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Myog.AllCell.bed.gz
# Oth.ALL.05.Myog.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Mysm1.AllCell.bed.gz
# Oth.ALL.05.Mysm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Myt1l.AllCell.bed.gz
# Oth.ALL.05.Myt1l.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.N6amt1.AllCell.bed.gz
# Oth.ALL.05.N6amt1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Naa10.AllCell.bed.gz
# Oth.ALL.05.Naa10.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Naca.AllCell.bed.gz
# Oth.ALL.05.Naca.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nacc1.AllCell.bed.gz
# Oth.ALL.05.Nacc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nanog.AllCell.bed.gz
# Oth.ALL.05.Nanog.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nbn.AllCell.bed.gz
# Oth.ALL.05.Nbn.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncapd3.AllCell.bed.gz
# Oth.ALL.05.Ncapd3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncapg.AllCell.bed.gz
# Oth.ALL.05.Ncapg.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncaph2.AllCell.bed.gz
# Oth.ALL.05.Ncaph2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncl.AllCell.bed.gz
# Oth.ALL.05.Ncl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncoa1.AllCell.bed.gz
# Oth.ALL.05.Ncoa1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncoa2.AllCell.bed.gz
# Oth.ALL.05.Ncoa2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncoa3.AllCell.bed.gz
# Oth.ALL.05.Ncoa3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncor1.AllCell.bed.gz
# Oth.ALL.05.Ncor1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ncor2.AllCell.bed.gz
# Oth.ALL.05.Ncor2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nelfa.AllCell.bed.gz
# Oth.ALL.05.Nelfa.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nelfb.AllCell.bed.gz
# Oth.ALL.05.Nelfb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nelfe.AllCell.bed.gz
# Oth.ALL.05.Nelfe.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Neurod1.AllCell.bed.gz
# Oth.ALL.05.Neurod1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Neurod2.AllCell.bed.gz
# Oth.ALL.05.Neurod2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Neurog2.AllCell.bed.gz
# Oth.ALL.05.Neurog2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfat5.AllCell.bed.gz
# Oth.ALL.05.Nfat5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfatc1.AllCell.bed.gz
# Oth.ALL.05.Nfatc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfatc2.AllCell.bed.gz
# Oth.ALL.05.Nfatc2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfe2.AllCell.bed.gz
# Oth.ALL.05.Nfe2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfe2l1.AllCell.bed.gz
# Oth.ALL.05.Nfe2l1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfe2l2.AllCell.bed.gz
# Oth.ALL.05.Nfe2l2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfia.AllCell.bed.gz
# Oth.ALL.05.Nfia.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfib.AllCell.bed.gz
# Oth.ALL.05.Nfib.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfic.AllCell.bed.gz
# Oth.ALL.05.Nfic.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfil3.AllCell.bed.gz
# Oth.ALL.05.Nfil3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfix.AllCell.bed.gz
# Oth.ALL.05.Nfix.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfkb1.AllCell.bed.gz
# Oth.ALL.05.Nfkb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfkbia.AllCell.bed.gz
# Oth.ALL.05.Nfkbia.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfya.AllCell.bed.gz
# Oth.ALL.05.Nfya.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfyb.AllCell.bed.gz
# Oth.ALL.05.Nfyb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nfyc.AllCell.bed.gz
# Oth.ALL.05.Nfyc.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nipbl.AllCell.bed.gz
# Oth.ALL.05.Nipbl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nkx2-1.AllCell.bed.gz
# Oth.ALL.05.Nkx2-1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nkx2-2.AllCell.bed.gz
# Oth.ALL.05.Nkx2-2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nkx2-5.AllCell.bed.gz
# Oth.ALL.05.Nkx2-5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nkx3-1.AllCell.bed.gz
# Oth.ALL.05.Nkx3-1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nkx3-2.AllCell.bed.gz
# Oth.ALL.05.Nkx3-2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nkx6-1.AllCell.bed.gz
# Oth.ALL.05.Nkx6-1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nlrc5.AllCell.bed.gz
# Oth.ALL.05.Nlrc5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nlrp3.AllCell.bed.gz
# Oth.ALL.05.Nlrp3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nono.AllCell.bed.gz
# Oth.ALL.05.Nono.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Notch1.AllCell.bed.gz
# Oth.ALL.05.Notch1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Npas3.AllCell.bed.gz
# Oth.ALL.05.Npas3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Npas4.AllCell.bed.gz
# Oth.ALL.05.Npas4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Npm1.AllCell.bed.gz
# Oth.ALL.05.Npm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr0b1.AllCell.bed.gz
# Oth.ALL.05.Nr0b1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr0b2.AllCell.bed.gz
# Oth.ALL.05.Nr0b2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr1d1.AllCell.bed.gz
# Oth.ALL.05.Nr1d1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr1d2.AllCell.bed.gz
# Oth.ALL.05.Nr1d2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr1h2.AllCell.bed.gz
# Oth.ALL.05.Nr1h2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr1h3.AllCell.bed.gz
# Oth.ALL.05.Nr1h3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr1h4.AllCell.bed.gz
# Oth.ALL.05.Nr1h4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr1i2.AllCell.bed.gz
# Oth.ALL.05.Nr1i2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr2f2.AllCell.bed.gz
# Oth.ALL.05.Nr2f2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr3c1.AllCell.bed.gz
# Oth.ALL.05.Nr3c1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr4a1.AllCell.bed.gz
# Oth.ALL.05.Nr4a1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr5a1.AllCell.bed.gz
# Oth.ALL.05.Nr5a1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nr5a2.AllCell.bed.gz
# Oth.ALL.05.Nr5a2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nrf1.AllCell.bed.gz
# Oth.ALL.05.Nrf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nsl1.AllCell.bed.gz
# Oth.ALL.05.Nsl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nucks1.AllCell.bed.gz
# Oth.ALL.05.Nucks1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nup107.AllCell.bed.gz
# Oth.ALL.05.Nup107.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nup153.AllCell.bed.gz
# Oth.ALL.05.Nup153.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nup210.AllCell.bed.gz
# Oth.ALL.05.Nup210.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Nup98.AllCell.bed.gz
# Oth.ALL.05.Nup98.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Obox1.AllCell.bed.gz
# Oth.ALL.05.Obox1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ogdh.AllCell.bed.gz
# Oth.ALL.05.Ogdh.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.O-GlcNAc.AllCell.bed.gz
# Oth.ALL.05.O-GlcNAc.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ogt.AllCell.bed.gz
# Oth.ALL.05.Ogt.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Olig2.AllCell.bed.gz
# Oth.ALL.05.Olig2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Onecut1.AllCell.bed.gz
# Oth.ALL.05.Onecut1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Onecut2.AllCell.bed.gz
# Oth.ALL.05.Onecut2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Otx2.AllCell.bed.gz
# Oth.ALL.05.Otx2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ovol1.AllCell.bed.gz
# Oth.ALL.05.Ovol1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ovol2.AllCell.bed.gz
# Oth.ALL.05.Ovol2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Paf1.AllCell.bed.gz
# Oth.ALL.05.Paf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pagr1a.AllCell.bed.gz
# Oth.ALL.05.Pagr1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Park7.AllCell.bed.gz
# Oth.ALL.05.Park7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Parp1.AllCell.bed.gz
# Oth.ALL.05.Parp1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pawr.AllCell.bed.gz
# Oth.ALL.05.Pawr.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pax3.AllCell.bed.gz
# Oth.ALL.05.Pax3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pax5.AllCell.bed.gz
# Oth.ALL.05.Pax5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pax6.AllCell.bed.gz
# Oth.ALL.05.Pax6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pax7.AllCell.bed.gz
# Oth.ALL.05.Pax7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pax8.AllCell.bed.gz
# Oth.ALL.05.Pax8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Paxip1.AllCell.bed.gz
# Oth.ALL.05.Paxip1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pbrm1.AllCell.bed.gz
# Oth.ALL.05.Pbrm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pbx1.AllCell.bed.gz
# Oth.ALL.05.Pbx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pcgf1.AllCell.bed.gz
# Oth.ALL.05.Pcgf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pcgf2.AllCell.bed.gz
# Oth.ALL.05.Pcgf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pcgf3.AllCell.bed.gz
# Oth.ALL.05.Pcgf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pcgf5.AllCell.bed.gz
# Oth.ALL.05.Pcgf5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pcgf6.AllCell.bed.gz
# Oth.ALL.05.Pcgf6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pcna.AllCell.bed.gz
# Oth.ALL.05.Pcna.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pds5a.AllCell.bed.gz
# Oth.ALL.05.Pds5a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pds5b.AllCell.bed.gz
# Oth.ALL.05.Pds5b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pdx1.AllCell.bed.gz
# Oth.ALL.05.Pdx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Peg3.AllCell.bed.gz
# Oth.ALL.05.Peg3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pgr.AllCell.bed.gz
# Oth.ALL.05.Pgr.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phc1.AllCell.bed.gz
# Oth.ALL.05.Phc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phc2.AllCell.bed.gz
# Oth.ALL.05.Phc2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phf10.AllCell.bed.gz
# Oth.ALL.05.Phf10.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phf19.AllCell.bed.gz
# Oth.ALL.05.Phf19.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phf20.AllCell.bed.gz
# Oth.ALL.05.Phf20.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phf2.AllCell.bed.gz
# Oth.ALL.05.Phf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phf5a.AllCell.bed.gz
# Oth.ALL.05.Phf5a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phf6.AllCell.bed.gz
# Oth.ALL.05.Phf6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phf7.AllCell.bed.gz
# Oth.ALL.05.Phf7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phf8.AllCell.bed.gz
# Oth.ALL.05.Phf8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Phrf1.AllCell.bed.gz
# Oth.ALL.05.Phrf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pitx1.AllCell.bed.gz
# Oth.ALL.05.Pitx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pknox1.AllCell.bed.gz
# Oth.ALL.05.Pknox1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Plagl1.AllCell.bed.gz
# Oth.ALL.05.Plagl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pml.AllCell.bed.gz
# Oth.ALL.05.Pml.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Polr1a.AllCell.bed.gz
# Oth.ALL.05.Polr1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pou2af1.AllCell.bed.gz
# Oth.ALL.05.Pou2af1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pou2f1.AllCell.bed.gz
# Oth.ALL.05.Pou2f1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pou2f2.AllCell.bed.gz
# Oth.ALL.05.Pou2f2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pou2f3.AllCell.bed.gz
# Oth.ALL.05.Pou2f3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pou3f1.AllCell.bed.gz
# Oth.ALL.05.Pou3f1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pou3f2.AllCell.bed.gz
# Oth.ALL.05.Pou3f2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pou5f1.AllCell.bed.gz
# Oth.ALL.05.Pou5f1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ppara.AllCell.bed.gz
# Oth.ALL.05.Ppara.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ppard.AllCell.bed.gz
# Oth.ALL.05.Ppard.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pparg.AllCell.bed.gz
# Oth.ALL.05.Pparg.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ppargc1b.AllCell.bed.gz
# Oth.ALL.05.Ppargc1b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prdm10.AllCell.bed.gz
# Oth.ALL.05.Prdm10.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prdm13.AllCell.bed.gz
# Oth.ALL.05.Prdm13.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prdm14.AllCell.bed.gz
# Oth.ALL.05.Prdm14.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prdm15.AllCell.bed.gz
# Oth.ALL.05.Prdm15.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prdm16.AllCell.bed.gz
# Oth.ALL.05.Prdm16.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prdm1.AllCell.bed.gz
# Oth.ALL.05.Prdm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prdm5.AllCell.bed.gz
# Oth.ALL.05.Prdm5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prdm9.AllCell.bed.gz
# Oth.ALL.05.Prdm9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prm1.AllCell.bed.gz
# Oth.ALL.05.Prm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prmt5.AllCell.bed.gz
# Oth.ALL.05.Prmt5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Propionyllysine.AllCell.bed.gz
# Oth.ALL.05.Propionyllysine.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prox1.AllCell.bed.gz
# Oth.ALL.05.Prox1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Prrx1.AllCell.bed.gz
# Oth.ALL.05.Prrx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Psip1.AllCell.bed.gz
# Oth.ALL.05.Psip1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pspc1.AllCell.bed.gz
# Oth.ALL.05.Pspc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ptbp1.AllCell.bed.gz
# Oth.ALL.05.Ptbp1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ptf1a.AllCell.bed.gz
# Oth.ALL.05.Ptf1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pwp1.AllCell.bed.gz
# Oth.ALL.05.Pwp1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Pygo2.AllCell.bed.gz
# Oth.ALL.05.Pygo2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Qk.AllCell.bed.gz
# Oth.ALL.05.Qk.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rad21.AllCell.bed.gz
# Oth.ALL.05.Rad21.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rad23b.AllCell.bed.gz
# Oth.ALL.05.Rad23b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rad51.AllCell.bed.gz
# Oth.ALL.05.Rad51.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Raf1.AllCell.bed.gz
# Oth.ALL.05.RAF1.AllCell.bed.gz
# Oth.ALL.05.Raf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.RAF1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rag1.AllCell.bed.gz
# Oth.ALL.05.Rag1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rag2.AllCell.bed.gz
# Oth.ALL.05.Rag2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rai1.AllCell.bed.gz
# Oth.ALL.05.Rai1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Raly.AllCell.bed.gz
# Oth.ALL.05.Raly.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rara.AllCell.bed.gz
# Oth.ALL.05.Rara.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rarb.AllCell.bed.gz
# Oth.ALL.05.Rarb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Rarg.AllCell.bed.gz
# Oth.ALL.05.Rarg.AllCell.bed.gz.merged.bed.gz
# ...
# Oth.ALL.05.Smad4.AllCell.bed.gz
# Oth.ALL.05.Smad4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smad6.AllCell.bed.gz
# Oth.ALL.05.Smad6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smad7.AllCell.bed.gz
# Oth.ALL.05.Smad7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smarca2.AllCell.bed.gz
# Oth.ALL.05.Smarca2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smarca4.AllCell.bed.gz
# Oth.ALL.05.Smarca4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smarca5.AllCell.bed.gz
# Oth.ALL.05.Smarca5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smarcad1.AllCell.bed.gz
# Oth.ALL.05.Smarcad1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smarcb1.AllCell.bed.gz
# Oth.ALL.05.Smarcb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smarcc1.AllCell.bed.gz
# Oth.ALL.05.Smarcc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smc1a.AllCell.bed.gz
# Oth.ALL.05.Smc1a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smc3.AllCell.bed.gz
# Oth.ALL.05.Smc3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smc5.AllCell.bed.gz
# Oth.ALL.05.Smc5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smchd1.AllCell.bed.gz
# Oth.ALL.05.Smchd1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Smyd2.AllCell.bed.gz
# Oth.ALL.05.Smyd2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Snai1.AllCell.bed.gz
# Oth.ALL.05.Snai1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Snai2.AllCell.bed.gz
# Oth.ALL.05.Snai2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Socs1.AllCell.bed.gz
# Oth.ALL.05.Socs1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox10.AllCell.bed.gz
# Oth.ALL.05.Sox10.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox11.AllCell.bed.gz
# Oth.ALL.05.Sox11.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox13.AllCell.bed.gz
# Oth.ALL.05.Sox13.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox15.AllCell.bed.gz
# Oth.ALL.05.Sox15.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox17.AllCell.bed.gz
# Oth.ALL.05.Sox17.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox2.AllCell.bed.gz
# Oth.ALL.05.Sox2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox30.AllCell.bed.gz
# Oth.ALL.05.Sox30.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox3.AllCell.bed.gz
# Oth.ALL.05.Sox3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox4.AllCell.bed.gz
# Oth.ALL.05.Sox4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox5.AllCell.bed.gz
# Oth.ALL.05.Sox5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox6.AllCell.bed.gz
# Oth.ALL.05.Sox6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sox9.AllCell.bed.gz
# Oth.ALL.05.Sox9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sp110.AllCell.bed.gz
# Oth.ALL.05.Sp110.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sp1.AllCell.bed.gz
# Oth.ALL.05.Sp1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sp3.AllCell.bed.gz
# Oth.ALL.05.Sp3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sp6.AllCell.bed.gz
# Oth.ALL.05.Sp6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sp7.AllCell.bed.gz
# Oth.ALL.05.Sp7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sp9.AllCell.bed.gz
# Oth.ALL.05.Sp9.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Spen.AllCell.bed.gz
# Oth.ALL.05.Spen.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Spi1.AllCell.bed.gz
# Oth.ALL.05.Spi1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Spib.AllCell.bed.gz
# Oth.ALL.05.Spib.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Spin1.AllCell.bed.gz
# Oth.ALL.05.Spin1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Srcap.AllCell.bed.gz
# Oth.ALL.05.Srcap.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Srebf1.AllCell.bed.gz
# Oth.ALL.05.Srebf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Srebf2.AllCell.bed.gz
# Oth.ALL.05.Srebf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Srf.AllCell.bed.gz
# Oth.ALL.05.Srf.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Srsf1.AllCell.bed.gz
# Oth.ALL.05.Srsf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Srsf2.AllCell.bed.gz
# Oth.ALL.05.Srsf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ss18.AllCell.bed.gz
# Oth.ALL.05.Ss18.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ssrp1.AllCell.bed.gz
# Oth.ALL.05.Ssrp1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ssu72.AllCell.bed.gz
# Oth.ALL.05.Ssu72.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stab1.AllCell.bed.gz
# Oth.ALL.05.Stab1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stag1.AllCell.bed.gz
# Oth.ALL.05.Stag1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stag2.AllCell.bed.gz
# Oth.ALL.05.Stag2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stat1.AllCell.bed.gz
# Oth.ALL.05.Stat1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stat2.AllCell.bed.gz
# Oth.ALL.05.Stat2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stat3.AllCell.bed.gz
# Oth.ALL.05.Stat3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stat4.AllCell.bed.gz
# Oth.ALL.05.Stat4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stat5a.AllCell.bed.gz
# Oth.ALL.05.Stat5a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stat5b.AllCell.bed.gz
# Oth.ALL.05.Stat5b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stat6.AllCell.bed.gz
# Oth.ALL.05.Stat6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Stra8.AllCell.bed.gz
# Oth.ALL.05.Stra8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Succinyllysine.AllCell.bed.gz
# Oth.ALL.05.Succinyllysine.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sumo1.AllCell.bed.gz
# Oth.ALL.05.Sumo1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Sumo2.AllCell.bed.gz
# Oth.ALL.05.Sumo2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Supt16.AllCell.bed.gz
# Oth.ALL.05.Supt16.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Supt4a.AllCell.bed.gz
# Oth.ALL.05.Supt4a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Supt5.AllCell.bed.gz
# Oth.ALL.05.Supt5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Supt6.AllCell.bed.gz
# Oth.ALL.05.Supt6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Suv39h2.AllCell.bed.gz
# Oth.ALL.05.Suv39h2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Suz12.AllCell.bed.gz
# Oth.ALL.05.Suz12.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Taf10.AllCell.bed.gz
# Oth.ALL.05.Taf10.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Taf12.AllCell.bed.gz
# Oth.ALL.05.Taf12.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Taf15.AllCell.bed.gz
# Oth.ALL.05.Taf15.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Taf1.AllCell.bed.gz
# Oth.ALL.05.Taf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Taf2.AllCell.bed.gz
# Oth.ALL.05.Taf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Taf3.AllCell.bed.gz
# Oth.ALL.05.Taf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Taf7l.AllCell.bed.gz
# Oth.ALL.05.Taf7l.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Taf9b.AllCell.bed.gz
# Oth.ALL.05.Taf9b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tal1.AllCell.bed.gz
# Oth.ALL.05.Tal1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.T.AllCell.bed.gz
# Oth.ALL.05.T.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbl1x.AllCell.bed.gz
# Oth.ALL.05.Tbl1x.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbp.AllCell.bed.gz
# Oth.ALL.05.Tbp.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbpl1.AllCell.bed.gz
# Oth.ALL.05.Tbpl1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbr1.AllCell.bed.gz
# Oth.ALL.05.Tbr1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbx19.AllCell.bed.gz
# Oth.ALL.05.Tbx19.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbx20.AllCell.bed.gz
# Oth.ALL.05.Tbx20.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbx21.AllCell.bed.gz
# Oth.ALL.05.Tbx21.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbx3.AllCell.bed.gz
# Oth.ALL.05.Tbx3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbx4.AllCell.bed.gz
# Oth.ALL.05.Tbx4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tbx5.AllCell.bed.gz
# Oth.ALL.05.Tbx5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tcf12.AllCell.bed.gz
# Oth.ALL.05.Tcf12.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tcf3.AllCell.bed.gz
# Oth.ALL.05.Tcf3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tcf4.AllCell.bed.gz
# Oth.ALL.05.Tcf4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tcf7.AllCell.bed.gz
# Oth.ALL.05.Tcf7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tcf7l1.AllCell.bed.gz
# Oth.ALL.05.Tcf7l1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tcf7l2.AllCell.bed.gz
# Oth.ALL.05.Tcf7l2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tcfl5.AllCell.bed.gz
# Oth.ALL.05.Tcfl5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tdg.AllCell.bed.gz
# Oth.ALL.05.Tdg.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tead1.AllCell.bed.gz
# Oth.ALL.05.Tead1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tead2.AllCell.bed.gz
# Oth.ALL.05.Tead2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tead4.AllCell.bed.gz
# Oth.ALL.05.Tead4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Terf1.AllCell.bed.gz
# Oth.ALL.05.Terf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Terf2ip.AllCell.bed.gz
# Oth.ALL.05.Terf2ip.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tet1.AllCell.bed.gz
# Oth.ALL.05.Tet1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tet2.AllCell.bed.gz
# Oth.ALL.05.Tet2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tet3.AllCell.bed.gz
# Oth.ALL.05.Tet3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tfam.AllCell.bed.gz
# Oth.ALL.05.Tfam.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tfap2a.AllCell.bed.gz
# Oth.ALL.05.Tfap2a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tfap2c.AllCell.bed.gz
# Oth.ALL.05.Tfap2c.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tfap4.AllCell.bed.gz
# Oth.ALL.05.Tfap4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tfcp2l1.AllCell.bed.gz
# Oth.ALL.05.Tfcp2l1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tfe3.AllCell.bed.gz
# Oth.ALL.05.Tfe3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tfeb.AllCell.bed.gz
# Oth.ALL.05.Tfeb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tgif1.AllCell.bed.gz
# Oth.ALL.05.Tgif1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tgif2.AllCell.bed.gz
# Oth.ALL.05.Tgif2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Thap11.AllCell.bed.gz
# Oth.ALL.05.Thap11.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Thap1.AllCell.bed.gz
# Oth.ALL.05.Thap1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Thoc5.AllCell.bed.gz
# Oth.ALL.05.Thoc5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Thra.AllCell.bed.gz
# Oth.ALL.05.Thra.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Thrap3.AllCell.bed.gz
# Oth.ALL.05.Thrap3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Thrb.AllCell.bed.gz
# Oth.ALL.05.Thrb.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Timeless.AllCell.bed.gz
# Oth.ALL.05.Timeless.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tle1.AllCell.bed.gz
# Oth.ALL.05.Tle1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tle3.AllCell.bed.gz
# Oth.ALL.05.Tle3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tlx1.AllCell.bed.gz
# Oth.ALL.05.Tlx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tmem131.AllCell.bed.gz
# Oth.ALL.05.Tmem131.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tmpo.AllCell.bed.gz
# Oth.ALL.05.Tmpo.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tnni2.AllCell.bed.gz
# Oth.ALL.05.Tnni2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Top1.AllCell.bed.gz
# Oth.ALL.05.Top1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Top2a.AllCell.bed.gz
# Oth.ALL.05.Top2a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Top2b.AllCell.bed.gz
# Oth.ALL.05.Top2b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tox.AllCell.bed.gz
# Oth.ALL.05.Tox.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Trim24.AllCell.bed.gz
# Oth.ALL.05.Trim24.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Trim28.AllCell.bed.gz
# Oth.ALL.05.Trim28.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Trim33.AllCell.bed.gz
# Oth.ALL.05.Trim33.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Trmt112.AllCell.bed.gz
# Oth.ALL.05.Trmt112.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Trp53.AllCell.bed.gz
# Oth.ALL.05.Trp53.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Trp63.AllCell.bed.gz
# Oth.ALL.05.Trp63.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Trps1.AllCell.bed.gz
# Oth.ALL.05.Trps1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Tsc22d3.AllCell.bed.gz
# Oth.ALL.05.Tsc22d3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ttf1.AllCell.bed.gz
# Oth.ALL.05.Ttf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Twist1.AllCell.bed.gz
# Oth.ALL.05.Twist1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ubtf.AllCell.bed.gz
# Oth.ALL.05.Ubtf.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Uhrf1.AllCell.bed.gz
# Oth.ALL.05.Uhrf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Uhrf2.AllCell.bed.gz
# Oth.ALL.05.Uhrf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Usf1.AllCell.bed.gz
# Oth.ALL.05.Usf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Usf2.AllCell.bed.gz
# Oth.ALL.05.Usf2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Usp16.AllCell.bed.gz
# Oth.ALL.05.Usp16.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Usp22.AllCell.bed.gz
# Oth.ALL.05.Usp22.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Usp7.AllCell.bed.gz
# Oth.ALL.05.Usp7.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Utf1.AllCell.bed.gz
# Oth.ALL.05.Utf1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Utp3.AllCell.bed.gz
# Oth.ALL.05.Utp3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Utp6.AllCell.bed.gz
# Oth.ALL.05.Utp6.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Vdr.AllCell.bed.gz
# Oth.ALL.05.Vdr.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Vsx2.AllCell.bed.gz
# Oth.ALL.05.Vsx2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Wapl.AllCell.bed.gz
# Oth.ALL.05.Wapl.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Was.AllCell.bed.gz
# Oth.ALL.05.Was.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Wdr11.AllCell.bed.gz
# Oth.ALL.05.Wdr11.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Wdr5.AllCell.bed.gz
# Oth.ALL.05.Wdr5.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Wdr61.AllCell.bed.gz
# Oth.ALL.05.Wdr61.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Wdr82.AllCell.bed.gz
# Oth.ALL.05.Wdr82.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Whsc1l1.AllCell.bed.gz
# Oth.ALL.05.Whsc1l1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Wiz.AllCell.bed.gz
# Oth.ALL.05.Wiz.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Wt1.AllCell.bed.gz
# Oth.ALL.05.Wt1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Wtap.AllCell.bed.gz
# Oth.ALL.05.Wtap.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Xbp1.AllCell.bed.gz
# Oth.ALL.05.Xbp1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Xrn2.AllCell.bed.gz
# Oth.ALL.05.Xrn2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Yap1.AllCell.bed.gz
# Oth.ALL.05.Yap1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ybx1.AllCell.bed.gz
# Oth.ALL.05.Ybx1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Yeats4.AllCell.bed.gz
# Oth.ALL.05.Yeats4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Ythdc1.AllCell.bed.gz
# Oth.ALL.05.Ythdc1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Yy1.AllCell.bed.gz
# Oth.ALL.05.Yy1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Yy2.AllCell.bed.gz
# Oth.ALL.05.Yy2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zbtb11.AllCell.bed.gz
# Oth.ALL.05.Zbtb11.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zbtb16.AllCell.bed.gz
# Oth.ALL.05.Zbtb16.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zbtb17.AllCell.bed.gz
# Oth.ALL.05.Zbtb17.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zbtb24.AllCell.bed.gz
# Oth.ALL.05.Zbtb24.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zbtb2.AllCell.bed.gz
# Oth.ALL.05.Zbtb2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zbtb7b.AllCell.bed.gz
# Oth.ALL.05.Zbtb7b.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zc3h10.AllCell.bed.gz
# Oth.ALL.05.Zc3h10.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zc3h11a.AllCell.bed.gz
# Oth.ALL.05.Zc3h11a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zc3h4.AllCell.bed.gz
# Oth.ALL.05.Zc3h4.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zeb1.AllCell.bed.gz
# Oth.ALL.05.Zeb1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp143.AllCell.bed.gz
# Oth.ALL.05.Zfp143.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp191.AllCell.bed.gz
# Oth.ALL.05.Zfp191.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp217.AllCell.bed.gz
# Oth.ALL.05.Zfp217.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp281.AllCell.bed.gz
# Oth.ALL.05.Zfp281.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp322a.AllCell.bed.gz
# Oth.ALL.05.Zfp322a.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp335.AllCell.bed.gz
# Oth.ALL.05.Zfp335.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp384.AllCell.bed.gz
# Oth.ALL.05.Zfp384.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp410.AllCell.bed.gz
# Oth.ALL.05.Zfp410.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp42.AllCell.bed.gz
# Oth.ALL.05.Zfp42.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp541.AllCell.bed.gz
# Oth.ALL.05.Zfp541.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp57.AllCell.bed.gz
# Oth.ALL.05.Zfp57.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp64.AllCell.bed.gz
# Oth.ALL.05.Zfp64.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp708.AllCell.bed.gz
# Oth.ALL.05.Zfp708.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfp961.AllCell.bed.gz
# Oth.ALL.05.Zfp961.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zfpm1.AllCell.bed.gz
# Oth.ALL.05.Zfpm1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zic1.AllCell.bed.gz
# Oth.ALL.05.Zic1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zic2.AllCell.bed.gz
# Oth.ALL.05.Zic2.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zic3.AllCell.bed.gz
# Oth.ALL.05.Zic3.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zkscan1.AllCell.bed.gz
# Oth.ALL.05.Zkscan1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zmiz1.AllCell.bed.gz
# Oth.ALL.05.Zmiz1.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zmynd11.AllCell.bed.gz
# Oth.ALL.05.Zmynd11.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zmynd8.AllCell.bed.gz
# Oth.ALL.05.Zmynd8.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zscan4c.AllCell.bed.gz
# Oth.ALL.05.Zscan4c.AllCell.bed.gz.merged.bed.gz
# Oth.ALL.05.Zscan5b.AllCell.bed.gz
# Oth.ALL.05.Zscan5b.AllCell.bed.gz.merged.bed.gz

# %% [markdown]
# Each of these files we downloaded contains data from several different experiments - the full details of them are in the expt_data table below - we might need to use this at some point

# %%
# I've commented this out as otherwise the notebook was to big to share on git, but feel free to uncomment and look at it
#exp_data = pd.read_csv('/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/experimentList_SRXonly.tab',names=range(50),sep='\t')

# %%
# subset it to the mouse genome (mm10)
#exp_data_mm10_TFs = exp_data_mm10[exp_data_mm10[2] =='TFs and others']
#exp_data_mm10_TFs.head()

# %% [markdown]
# And here are all our peaks that overlap the files we downloaded - these are the files you will be working with to make the features table

# %%
! ls /project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/indiv_factors_all_cells.dir/intersection_with_basson_peaks.dir
# Out:
# basson_cere_WTmin123_in_Oth.ALL.05.0610010K14Rik.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.5-hmC.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.5-mC.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.8-Hydroxydeoxyguanosine.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Acaa2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Acss2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Actb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Adnp.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.ADP-ribose.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Aebp2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Aff3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Aff4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ago2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ahcy.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ahr.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Aicda.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Aire.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Alkbh5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.AML1-ETO.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Anp32e.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ar.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Arid1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Arid1b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Arid2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Arid3a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Arid4b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Arid5a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Arnt.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Arntl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Art1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ascl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ascl2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ash1l.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ash2l.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Asxl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Asxl3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Atf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Atf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Atf4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Atf7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Atf7ip.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Atm.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Atoh1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Atrx.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Auts2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bach1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bach2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Banp.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bap1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Batf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Batf.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Baz1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Baz1b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Baz2a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bbx.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bcl11a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bcl11b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bcl6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bcor.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bhlhe40.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bhlhe41.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Biotin.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bmi1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Bnc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brca1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brca2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brd2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brd3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brd4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brd7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brd9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brdt.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.BrdU.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Brwd1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Btaf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Butyryllysine.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Carm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cas9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbfa2t2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbfa2t3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbfb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbx2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbx3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbx4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbx5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbx7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cbx8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ccar1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ccnk.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cd38.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cdc73.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cdk7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cdk8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cdk9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cdx2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cdyl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cebpa.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.CEBPA.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cebpb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cebpd.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cebpe.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cebpg.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Chaf1b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Chd1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Chd2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Chd4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Chd7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Chd8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Chuk.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cirh1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Clock.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cpsf3l.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Creb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Creb3l2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Crebbp.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Crotonyl_lysine.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Crtc2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Crtc3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Crx.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cry1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ctbp2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ctcf.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ctcfl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ctf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ctnnb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ctr9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cux2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cxxc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Cxxc5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Daxx.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dbp.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ddit3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ddx18.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ddx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ddx21.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ddx5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dendra2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dgcr8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dhx9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dicer1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dlx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dlx3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dmap1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dmc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dmrt1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dmrtb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dnajc2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.DNA-RNA_hybrid.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dnmt1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dnmt3a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dnmt3b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dnmt3l.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dnttip1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dpf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dpf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dppa2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dppa3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dppa4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dpy30.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Dr1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Drosha.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Duxbl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.E2f1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.E2f3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.E2f4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.E2f6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.E4f1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ebf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ebf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ebf4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Eed.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Egr1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Egr2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ehf.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ehmt2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Elf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Elf4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Elf5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Elk1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Elk3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Elk4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ell2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ell3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ell.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Eloa.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Elob.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Emx2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Eomes.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ep300.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ep400.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Epitope_tags.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Epop.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ercc3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Erf.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Erg.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Esr1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Esr2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Esrra.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Esrrb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Esrrg.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ets1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ets2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Etv2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Etv5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Etv6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ezh1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ezh2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fam208a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fam60a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fbxo21.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fev.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fgfr1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fli1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fo.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fos.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fosb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fosl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Fosl2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxa1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxa2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxa3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxc2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxg1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxh1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxj2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxk1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxk2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxl2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxo1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxo3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxp1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxp2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Foxp3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gabpa.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gad1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gadd45a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gata1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gata2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gata3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gata4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gata6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gckr.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gcm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gfi1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gfi1b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.GFP.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gli1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gli2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gli3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Glis3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Glyr1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gmnn.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gps2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Grhl2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Grhl3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Grip1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gsk3b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gtf2a2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gtf2b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gtf2e2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gtf2f1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Gtf3c1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.H1foo.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hand1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hand2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.HBx.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hcfc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdac1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdac2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdac3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdac4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdac5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdac6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdac7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdgf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hdgfrp2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hells.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hes1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hexim1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Heyl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hic2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hif1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hira.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hmga2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hmgn2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hnf1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hnf1b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hnf4a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hnf4g.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hnrnpk.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hnrnpl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hnrnpu.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hnrnpul1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hopx.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxa11.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxa13.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxa9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxb13.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxb4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxc10.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxc13.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxc6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxc8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxc9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxd13.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hoxd9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hsf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Hsf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Htatsf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Htt.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Id2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ikzf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ikzf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ikzf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ing1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ing5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ino80.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Insm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ints3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ints5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf2bp2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Irf9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Isl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Jarid2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Jmjd1c.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Jmjd6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Jun.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Junb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Jund.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kansl3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kat2a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kat2b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kat5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kat7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kat8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm2a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm2b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm3a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm3b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm4a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm4b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm4c.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm4d.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm5a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm5b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm5c.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm6a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kdm6b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Klf15.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Klf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Klf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Klf4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Klf5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Klf6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Klf9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kmt2a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kmt2b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kmt2c.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Kmt2d.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.L3mbtl2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.L3mbtl3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ldb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lef1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Leo1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lhx2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lhx3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lhx5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lhx6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lin9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lmna.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lmnb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lmo2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lmx1b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lrrfip1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lyl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Lysin_homocysteine.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Macf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mafa.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Maf.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mafb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Maff.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mafg.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mafk.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mapk8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Matr3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mau2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Max.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Maz.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mbd1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mbd2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mbd3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mcrs1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mecp2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Med12.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Med14.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Med1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Med23.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Med24.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Med26.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Med4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mef2a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mef2c.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mef2d.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Meiosin.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Meis1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Men1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mesp1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mettl14.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mettl3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mitf.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mkl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mkl2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mllt10.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mllt3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mlxipl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mnt.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mnx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Morc3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mphosph8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mpnd.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mre11a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Msh2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Msh6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Msl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Msl2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mta1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mta2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mtf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mtor.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mxi1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Myb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mybl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Myc.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mycn.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Myf5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Myo1c.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Myod1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Myog.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Mysm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Myt1l.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.N6amt1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Naa10.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Naca.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nacc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nanog.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nbn.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncapd3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncapg.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncaph2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncoa1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncoa2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncoa3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncor1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ncor2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nelfa.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nelfb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nelfe.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Neurod1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Neurod2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Neurog2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfat5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfatc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfatc2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfe2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfe2l1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfe2l2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfia.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfib.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfic.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfil3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfix.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfkb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfkbia.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfya.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfyb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nfyc.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nipbl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nkx2-1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nkx2-2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nkx2-5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nkx3-1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nkx3-2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nkx6-1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nlrc5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nlrp3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nono.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Notch1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Npas3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Npas4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Npm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr0b1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr0b2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr1d1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr1d2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr1h2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr1h3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr1h4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr1i2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr2f2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr3c1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr4a1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr5a1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nr5a2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nrf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nsl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nucks1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nup107.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nup153.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nup210.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Nup98.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Obox1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ogdh.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.O-GlcNAc.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ogt.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Olig2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Onecut1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Onecut2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Otx2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ovol1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ovol2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Paf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pagr1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Park7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Parp1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pawr.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pax3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pax5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pax6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pax7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pax8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Paxip1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pbrm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pbx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pcgf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pcgf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pcgf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pcgf5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pcgf6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pcna.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pds5a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pds5b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pdx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Peg3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pgr.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phc2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phf10.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phf19.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phf20.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phf5a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phf6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phf7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phf8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Phrf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pitx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pknox1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Plagl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pml.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Polr1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pou2af1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pou2f1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pou2f2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pou2f3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pou3f1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pou3f2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pou5f1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ppara.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ppard.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pparg.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ppargc1b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prdm10.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prdm13.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prdm14.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prdm15.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prdm16.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prdm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prdm5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prdm9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prmt5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Propionyllysine.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prox1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Prrx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Psip1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pspc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ptbp1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ptf1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pwp1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Pygo2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Qk.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rad21.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rad23b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rad51.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Raf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.RAF1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rag1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rag2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rai1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Raly.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rara.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rarb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rarg.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rbbp4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rbbp5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rbbp7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rbfox2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rbp2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rbpj.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rbpjl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rcor2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rec8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rela.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rel.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Relb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rest.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.RFP.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rfx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rfx2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rfx3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rif1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rnf20.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rnf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rora.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rorc.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rpa1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rpa2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rreb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rtf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Runx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Runx2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Runx3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ruvbl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ruvbl2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rxra.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Rybp.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Safb2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Safb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sall1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sall4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Samd7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sap130.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sap18.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Satb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Satb2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Scml2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Setd1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Setd2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Setd5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Setdb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sfmbt1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sfmbt2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Shox2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sin3a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sin3b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sirt1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sirt6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sirt7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Six1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Six2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Six4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smad1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smad2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smad3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smad4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smad6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smad7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smarca2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smarca4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smarca5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smarcad1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smarcb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smarcc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smc1a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smc3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smc5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smchd1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Smyd2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Snai1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Snai2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Socs1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox10.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox11.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox13.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox15.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox17.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox30.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sox9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sp110.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sp1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sp3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sp6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sp7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sp9.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Spen.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Spi1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Spib.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Spin1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Srcap.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Srebf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Srebf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Srf.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Srsf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Srsf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ss18.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ssrp1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ssu72.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stab1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stag1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stag2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stat1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stat2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stat3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stat4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stat5a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stat5b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stat6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Stra8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Succinyllysine.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sumo1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Sumo2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Supt16.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Supt4a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Supt5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Supt6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Suv39h2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Suz12.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Taf10.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Taf12.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Taf15.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Taf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Taf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Taf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Taf7l.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Taf9b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tal1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.T.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbl1x.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbp.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbpl1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbr1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbx19.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbx20.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbx21.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbx3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbx4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tbx5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tcf12.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tcf3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tcf4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tcf7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tcf7l1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tcf7l2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tcfl5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tdg.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tead1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tead2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tead4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Terf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Terf2ip.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tet1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tet2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tet3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tfam.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tfap2a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tfap2c.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tfap4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tfcp2l1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tfe3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tfeb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tgif1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tgif2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Thap11.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Thap1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Thoc5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Thra.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Thrap3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Thrb.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Timeless.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tle1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tle3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tlx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tmem131.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tmpo.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tnni2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Top1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Top2a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Top2b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tox.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Trim24.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Trim28.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Trim33.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Trmt112.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Trp53.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Trp63.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Trps1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Tsc22d3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ttf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Twist1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ubtf.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Uhrf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Uhrf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Usf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Usf2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Usp16.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Usp22.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Usp7.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Utf1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Utp3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Utp6.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Vdr.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Vsx2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Wapl.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Was.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Wdr11.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Wdr5.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Wdr61.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Wdr82.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Whsc1l1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Wiz.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Wt1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Wtap.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Xbp1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Xrn2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Yap1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ybx1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Yeats4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Ythdc1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Yy1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Yy2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zbtb11.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zbtb16.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zbtb17.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zbtb24.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zbtb2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zbtb7b.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zc3h10.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zc3h11a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zc3h4.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zeb1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp143.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp191.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp217.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp281.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp322a.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp335.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp384.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp410.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp42.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp541.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp57.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp64.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp708.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfp961.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zfpm1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zic1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zic2.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zic3.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zkscan1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zmiz1.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zmynd11.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zmynd8.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zscan4c.AllCell.bed.gz
# basson_cere_WTmin123_in_Oth.ALL.05.Zscan5b.AllCell.bed.gz

# %% [markdown]
# If you have a look at the top of these files you will see there are different columns

# %%
overlap_of_our_peaks_with_Zscan5b_AllCell = pd.read_table('/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/indiv_factors_all_cells.dir/intersection_with_basson_peaks.dir/basson_cere_WTmin123_in_Oth.ALL.05.Zscan5b.AllCell.bed.gz',header=None)

# %%
overlap_of_our_peaks_with_Zscan5b_AllCell.head()
# Out:
#        0          1          2                                      3
# 0   chr1  171038166  171038666  atac_de_peak_chr1_171038166_171038666
# 1  chr11    3126968    3127468     atac_de_peak_chr11_3126968_3127468
# 2  chr11    3153586    3154086     atac_de_peak_chr11_3153586_3154086
# 3  chr11   48834196   48834696   atac_de_peak_chr11_48834196_48834696
# 4  chr12   78350732   78351232   atac_de_peak_chr12_78350732_78351232

# %%
# assign column names 
overlap_of_our_peaks_with_Zscan5b_AllCell.columns = ['chr','start','end','peak_id']
overlap_of_our_peaks_with_Zscan5b_AllCell.head()

# %% [markdown]
# TODO:
#
# 1. In a new notebook (that you call `2_making_feature_table` use pd.read_csv() to read in our full list of peaks (>112,000) - use len or .shape to check the length so its the right file
# 2. Get a list of all the files in `/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/indiv_factors_all_cells.dir/intersection_with_basson_peaks.dir`
#
# 3. For one file at first work out how to extract the peak_id column from the overlaps file and make a new column on the dataframe containing all our peaks to indictcate using 1 or 0 if that peak overlaps with that TF  (the peak_ids are the same format between the two files) - make sure the column is labeled with the TF name (e.g. Zscan5b)
#
# 4. Once that works for one file, loop over all the files in your list of all the overlaps to add a column for every TF
# 5. Write your final table out to the  `/project/sims-lab/shared/uniq_plus_2023/annotation_of_peaks/chip_atlas/peak_call_data.dir/feature_table.dir` directory - when you write it our use compression='gzip' to make it smaller and take up less space.
#
# Good luck :) and feel free to ask me any questions if your stuck :)
